# %% [markdown]
# Plot the summary of statistics (energy balance, optimal capacity, ...)
#
# **Prerequisites**
#
# * Execute "make_stats_dict.py" before using this notebook. The script make_stats_dict creates csv for the metrics for all runs of multiple config files.
# * Install the environment envs/pypsa-earth-vis.yaml

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import pandas as pd
idx_slice = pd.IndexSlice
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # Comment out for debugging and development
warnings.simplefilter(action='ignore', category=DeprecationWarning) # Comment out for debugging and development
import plotly.express as px

from plot_helpers import (
    chdir_to_parent_dir,
    read_stats_dict,
    drop_index_levels, 
    update_layout, 
    prepare_dataframe,
    get_supply_demand_from_balance,
    rename_electricity, 
    rename_h2,
    rename_gas,
    rename_oil,
    rename_co2,
    rename_costs,
    rename_to_upper_case,
    colors,
    nice_title,
    save_plotly_fig)

chdir_to_parent_dir()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Navigation
#
# ### Main Sections
# [⬇️ Go to Plotting](#plotting)
# - [⬇️ Energy market balance | Electricity](#energy-market-balance--electricity)
# - [⬇️ Energy and feedstock market balance | Hydrogen](#energy-and-feedstock-market-balance--hydrogen)
# - [⬇️ Energy and feedstock market balance | Liquid fuel](#energy-and-feedstock-market-balance--liquid-fuel)
# - [⬇️ Energy and feedstock market balance | CH4](#energy-and-feedstock-market-balance--ch4)
# - [⬇️ Energy and feedstock market balance | CO2](#energy-and-feedstock-market-balance--co2)
# - [⬇️ CO2 atmosphere balance](#co2-atmosphere-balance)
#
# [⬇️ Go to Installed Capacity](#installed-capacity)
#
# [⬇️ Go to Relative costs](#relative-costs)
#
# [⬇️ Go to Water consumption](#water-consumption)

# %%
def add_production_consumption_legend_groups(fig, df):
    """
    Add legend groups for Production (positive values) and Consumption (negative values).
    
    Parameters:
    -----------
    fig : plotly.graph_objects.Figure
        The plotly figure to modify
    df : pandas.DataFrame
        The dataframe containing the data with 'variable' and 'value' columns
    
    Returns:
    --------
    fig : plotly.graph_objects.Figure
        The modified figure with legend groups
    """
    # Add legend groups for Production (positive values) and Consumption (negative values)
    for trace in fig.data:
        # Get the variable name from the trace
        variable_name = trace.name
        
        # Check if this variable typically has positive or negative values in the data
        variable_data = df[df['variable'] == variable_name]['value']
        
        if len(variable_data) > 0:
            # Determine if this variable is primarily production (positive) or consumption (negative)
            avg_value = variable_data.mean()
            
            if avg_value > 0:
                trace.legendgroup = "Production"
                trace.legendgrouptitle = {"text": "Production"}
            else:
                trace.legendgroup = "Consumption" 
                trace.legendgrouptitle = {"text": "Consumption"}
    
    return fig

# %%
run_name_prefix = "DKS" # Experiment name

sdir = Path.cwd() / "results"/ f"{run_name_prefix}_summary_202508"
sdir.mkdir(exist_ok=True, parents=True)

# %%
balance_dict = read_stats_dict("balance_dict", sdir, keys=["AC", "H2", "oil", "gas", "co2 stored", "co2"])
optimal_capacity_dict = read_stats_dict("optimal_capacity_dict", sdir, keys=["AC", "H2"])
costs_dict = read_stats_dict("costs_dict", sdir, keys=["capex", "opex"])

# simplify index for plotting: define a scen_str column and drop all other columns
#NB: the following is specific to the experiment

index_levels_to_drop=["simpl", "clusters", "ll", "opts", "discountrate"] #, , "demand" "sopts"


for key in balance_dict.keys():
    balance_dict[key] = drop_index_levels(balance_dict[key], to_drop=index_levels_to_drop)

for key in optimal_capacity_dict.keys():
    optimal_capacity_dict[key] = drop_index_levels(optimal_capacity_dict[key], to_drop=index_levels_to_drop)
    
for key in costs_dict.keys():
    costs_dict[key] = drop_index_levels(costs_dict[key], to_drop=index_levels_to_drop)
# Out:
# Imported AC from /mnt/data/gsa/pypsa-earth-custom-lukas/results/DKS_summary_202508/balance_dict_AC.csv
# Imported H2 from /mnt/data/gsa/pypsa-earth-custom-lukas/results/DKS_summary_202508/balance_dict_H2.csv
# Imported oil from /mnt/data/gsa/pypsa-earth-custom-lukas/results/DKS_summary_202508/balance_dict_oil.csv
# Imported gas from /mnt/data/gsa/pypsa-earth-custom-lukas/results/DKS_summary_202508/balance_dict_gas.csv
# Imported co2 stored from /mnt/data/gsa/pypsa-earth-custom-lukas/results/DKS_summary_202508/balance_dict_co2 stored.csv
# Imported co2 from /mnt/data/gsa/pypsa-earth-custom-lukas/results/DKS_summary_202508/balance_dict_co2.csv
# Imported AC from /mnt/data/gsa/pypsa-earth-custom-lukas/results/DKS_summary_202508/optimal_capacity_dict_AC.csv
# Imported H2 from /mnt/data/gsa/pypsa-earth-custom-lukas/results/DKS_summary_202508/optimal_capacity_dict_H2.csv
# Imported capex from /mnt/data/gsa/pypsa-earth-custom-lukas/results/DKS_summary_202508/costs_dict_capex.csv
# Imported opex from /mnt/data/gsa/pypsa-earth-custom-lukas/results/DKS_summary_202508/costs_dict_opex.csv

# %%
# def set_scen_col(df):
#     """
#     Set combined scenario str (for plots).
#     NB: This is specific to the experiment and should be adapted for other experiments.
#     """
#     df = df.copy()

#     df["scen"] = df["eopts"] + "+" + df["sopts"]
#     df = df.drop(columns=["eopts", "sopts"])
#     #df["scen"] = df.apply(lambda row: "_".join([f"{col}_{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)
#     #df["scen"] = df.apply(lambda row: "_".join([f"{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)

#     return df

def set_scen_col(df):
    """
    Set combined scenario str (for plots).
    NB: This is specific to the experiment and should be adapted for other experiments.
    """
    df = df.copy()
    
    # Set base scen value based on 'demand'
    scen = df["demand"].map({"RF": "AB", "EL": "AT"})
    # Add export info
    export_info = ""
    # Add export info based on 'eopts', handling NaN and string values
    export_info = df["eopts"].apply(
        lambda x: "50%Exp" if isinstance(x, str) and "v0.5" in x
        else ("NoExp" if pd.isna(x) or str(x) == "" else "100%Exp")
    )
    # Combine
    df["scen"] = scen + export_info.replace("", "", regex=False).apply(lambda x: f"+{x}" if x else "") + df["sopts"].replace("1H", "", regex=False)
    df = df.drop(columns=["eopts", "sopts", "demand"])
    #df["scen"] = df.apply(lambda row: "_".join([f"{col}_{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)
    #df["scen"] = df.apply(lambda row: "_".join([f"{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)

    return df

# %% [markdown]
# # Plotting

# %%
# select and define index group (multiindex) for plots: which solutions to show at once

idx_group = idx_slice[["DKS"],:,["ZA"],[2030, 2050],["1H"]]
idx_group_name = ""

print(idx_group_name) 
print(idx_group)

scen_filter = ["AB+50%Exp", "AT+100%Exp", "AT+50%Exp", "AT+NoExp"]
# Out:
# (['DKS'], slice(None, None, None), ['ZA'], [2030, 2050], ['1H'])

# %%
print(balance_dict["AC"].index.names)
# print(balance_dict["AC"].index)
# Out:
# ['run_name_prefix', 'run_name', 'country', 'year', 'sopts', 'demand', 'eopts']

# %%
width = 800
heights = {"1": 300,"2": 500,"3": 600,}

fig_kwargs = dict(
    x="scen", 
    y="value", 
    color="variable", 
    facet_col="year", 
    # facet_row="run_name",
    barmode="relative", 
    text="value", 
    #facet_col_wrap=1, facet_col_spacing=0.07,
    width=width, 
    height=heights["2"],
    text_auto =".0f",
)

scen_order = ["AB+50%Exp", "AT+100%Exp", "AT+50%Exp", "AT+NoExp"] # option to specify order of scenarios in the plot

# %% [markdown]
# ## Energy market balance | Electricity

# %%
df = prepare_dataframe(balance_dict["AC"], idx_group, set_scen_col, rename_function=rename_electricity)
df.variable = df.variable.map(rename_to_upper_case)
df = df.query("scen in @scen_filter")

supply_df = df[df["value"]>=0].copy()

# %%
df = prepare_dataframe(balance_dict["AC"], idx_group, set_scen_col, rename_function=rename_electricity)
df.variable = df.variable.map(rename_to_upper_case)
df = df.query("scen in @scen_filter")

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "electricity_supply_TWh"
fig = px.bar(
    supply_df, 
    **fig_kwargs,
    labels={"value":"Electricity supply in TWh<sub>el</sub>",
            "year":"",
            "variable":"", 
            "scen":""
            },
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        # "scen": scen_order
        },
    #facet_col_wrap=1, facet_col_spacing=0.07,
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)

fig.show()

#save_plotly_fig(supply_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                       value
# run_name_prefix run_name    scen       year country
# DKS             DKS_ZA_2030 AT+100%Exp 2030 ZA        339.9
#                             AT+50%Exp  2030 ZA        318.1
#                             AT+NoExp   2030 ZA        296.4
#                 DKS_ZA_2050 AB+50%Exp  2050 ZA       1237.0
#                             AT+100%Exp 2050 ZA       1114.6
#                             AT+50%Exp  2050 ZA       1064.3
#                             AT+NoExp   2050 ZA       1015.1
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="4239b907-2654-4a47-b60b-48322d12b016" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4239b907-2654-4a47-b60b-48322d12b016")) {                    Plotly.newPlot(                        "4239b907-2654-4a47-b60b-48322d12b016",                        [{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMyMSkAAAAAAAMBIQM3MzMzMDEdA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMyMSkAAAAAAAMBIQM3MzMzMDEdA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"ZmZmZmYOeUBmZmZmZqZ2QJqZmZmZyXVAMzMzMzPTdEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"ZmZmZmYOeUBmZmZmZqZ2QJqZmZmZyXVAMzMzMzPTdEA="},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzcaEAzMzMzM4NmQDMzMzMzI2RA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzcaEAzMzMzM4NmQDMzMzMzI2RA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"mpmZmZlBiUDNzMzMzKyGQM3MzMzMiIVAAAAAAAB4hEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"mpmZmZlBiUDNzMzMzKyGQM3MzMzMiIVAAAAAAAB4hEA="},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coal","marker":{"color":"#454545","pattern":{"shape":""}},"name":"Coal","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACAUkAAAAAAAIBSQAAAAAAAgFJA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAACAUkAAAAAAAIBSQAAAAAAAgFJA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coal","marker":{"color":"#454545","pattern":{"shape":""}},"name":"Coal","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"ZmZmZmZm\u002fj+amZmZmZn5PwAAAAAAAPg\u002fZmZmZmZm9j8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"ZmZmZmZm\u002fj+amZmZ ...

# %%
fig_name = "electricity_demand_TWh"
fig = px.bar(
    demand_df, 
    **fig_kwargs,
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    labels={"value":"Electricity demand in TWh<sub>el</sub>","year":"",
            "variable":"", 
            "scen":""},
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(demand_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                       value
# run_name_prefix run_name    scen       year country
# DKS             DKS_ZA_2030 AT+100%Exp 2030 ZA        340.0
#                             AT+50%Exp  2030 ZA        318.2
#                             AT+NoExp   2030 ZA        296.5
#                 DKS_ZA_2050 AB+50%Exp  2050 ZA       1236.9
#                             AT+100%Exp 2050 ZA       1114.5
#                             AT+50%Exp  2050 ZA       1064.4
#                             AT+NoExp   2050 ZA       1015.1
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="3657018d-2111-4f75-b6ee-69fe44a640a2" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3657018d-2111-4f75-b6ee-69fe44a640a2")) {                    Plotly.newPlot(                        "3657018d-2111-4f75-b6ee-69fe44a640a2",                        [{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#f58220","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACAYEAAAAAAAIBgQAAAAAAAgGBA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAACAYEAAAAAAAIBgQAAAAAAAgGBA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#f58220","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"ZmZmZma2a0DNzMzMzBRwQM3MzMzMFHBAzczMzMwUcEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"ZmZmZma2a0DNzMzMzBRwQM3MzMzMFHBAzczMzMwUcEA="},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commerce","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Commerce","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmaGVkBmZmZmZoZWQGZmZmZmhlZA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmaGVkBmZmZmZoZWQGZmZmZmhlZA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commerce","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Commerce","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"MzMzMzMjZkAzMzMzMyNmQDMzMzMzI2ZAMzMzMzMjZkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"MzMzMzMjZkAzMzMzMyNmQDMzMzMzI2ZAMzMzMzMjZkA="},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-NH3","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Power-to-NH3","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZAUCamZmZmZnxPw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZAUCamZmZmZnxPw=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-NH3","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Power-to-NH3","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"MzMzMzMzF0AAAAAAAAAeQM3MzMzMzBZAMzMzMzMzD0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"MzMzMzMzF0AAAAAAAAAeQM3MzMzMzBZAMzMzMzMzD0 ...

# %% [markdown]
# ## Energy and feedstock market balance | Hydrogen

# %%
df = prepare_dataframe(balance_dict["H2"], idx_group, set_scen_col, rename_function=rename_h2)
df = df[df["value"]!=0]
df = df.query("scen in @scen_filter")

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "hydrogen_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["hydrogen"],
    category_orders={
        "variable":list(colors["hydrogen"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"H2 balance in TWh","year":"",
            "variable":"", 
            "scen": ""},

)

# Add legend groups for Production and Consumption
fig = add_production_consumption_legend_groups(fig, df)

update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_ZA_2030 AT+100%Exp 2030 ZA        33.8
#                             AT+50%Exp  2030 ZA        20.7
#                             AT+NoExp   2030 ZA         7.6
#                 DKS_ZA_2050 AB+50%Exp  2050 ZA       416.3
#                             AT+100%Exp 2050 ZA       326.5
#                             AT+50%Exp  2050 ZA       294.8
#                             AT+NoExp   2050 ZA       263.8
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="3fdb146f-454d-45a1-a482-b9e5f5e63c64" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3fdb146f-454d-45a1-a482-b9e5f5e63c64")) {                    Plotly.newPlot(                        "3fdb146f-454d-45a1-a482-b9e5f5e63c64",                        [{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzOkAzMzMzMzMqQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzOkAzMzMzMzMqQA=="},"yaxis":"y","type":"bar","legendgrouptitle":{"text":"Production"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"ZmZmZmb2eUAAAAAAAFB0QGZmZmZmRnJAZmZmZmZGcEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"ZmZmZmb2eUAAAAAAAFB0QGZmZmZmRnJAZmZmZmZGcEA="},"yaxis":"y2","type":"bar","legendgrouptitle":{"text":"Production"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmHsBmZmZmZmYewGZmZmZmZh7A"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmHsBmZmZmZmYewGZmZmZmZh7A"},"yaxis":"y","type":"bar","legendgrouptitle":{"text":"Consumption"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"mpmZmZmZO8AAAAAAAIBJwAAAAAAAgEnAAAAAAACAScA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"mpmZmZmZO8AAAAAAAIBJwAAAAAAAgEnAAAAAAACAScA="},"yaxis":"y2","type":"bar","legendgrouptitle":{"text":"Consumption"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#669db2","pattern":{"shape":""}},"name":"Land transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMxMM8BmZmZmZmb+v2ZmZmZmZv6\u002fZmZmZmZm\u002fr8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"zczMzMxMM8BmZmZmZmb+v2ZmZmZmZv6\u002fZmZmZmZm\u002fr8="},"yaxis":"y2","type":"bar","legendgrouptitle":{"text":"Consumption"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Power-to-NH3","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMNMDNzMzMzMwkwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMNMDNzMzMzMwkwA=="},"yaxis":"y","type":"bar","legendgrouptitle":{" ...

# %%
df[["scen", "year", "variable", "value"]]
# Out:
#           scen  year         variable  value
# 0   AT+100%Exp  2030  H2 Electrolysis   26.2
# 3   AT+100%Exp  2030         Industry   -7.6
# 6   AT+100%Exp  2030     Power-to-NH3  -20.8
# 7   AT+100%Exp  2030  Power-to-liquid   -5.4
# 8   AT+100%Exp  2030              SMR    7.6
# 10   AT+50%Exp  2030  H2 Electrolysis   13.1
# 13   AT+50%Exp  2030         Industry   -7.6
# 16   AT+50%Exp  2030     Power-to-NH3  -10.4
# 17   AT+50%Exp  2030  Power-to-liquid   -2.7
# 18   AT+50%Exp  2030              SMR    7.6
# 23    AT+NoExp  2030         Industry   -7.6
# 28    AT+NoExp  2030              SMR    7.6
# 40   AB+50%Exp  2050  H2 Electrolysis  415.4
# 43   AB+50%Exp  2050         Industry  -27.6
# 44   AB+50%Exp  2050   Land transport  -19.3
# 45   AB+50%Exp  2050     Power-to-CH4  -59.1
# 46   AB+50%Exp  2050     Power-to-NH3  -55.5
# 47   AB+50%Exp  2050  Power-to-liquid -254.8
# 48   AB+50%Exp  2050              SMR    0.8
# 60  AT+100%Exp  2050  H2 Electrolysis  325.0
# 63  AT+100%Exp  2050         Industry  -51.0
# 64  AT+100%Exp  2050   Land transport   -1.9
# 65  AT+100%Exp  2050     Power-to-CH4  -36.3
# 66  AT+100%Exp  2050     Power-to-NH3  -72.2
# 67  AT+100%Exp  2050  Power-to-liquid -165.1
# 68  AT+100%Exp  2050              SMR    1.5
# 70   AT+50%Exp  2050  H2 Electrolysis  292.4
# 73   AT+50%Exp  2050         Industry  -51.0
# 74   AT+50%Exp  2050   Land transport   -1.9
# 75   AT+50%Exp  2050     Power-to-CH4  -40.9
# 76   AT+50%Exp  2050     Power-to-NH3  -54.8
# 77   AT+50%Exp  2050  Power-to-liquid -146.2
# 78   AT+50%Exp  2050              SMR    2.4
# 80    AT+NoExp  2050  H2 Electrolysis  260.4
# 83    AT+NoExp  2050         Industry  -51.0
# 84    AT+NoExp  2050   Land transport   -1.9
# 85    AT+NoExp  2050     Power-to-CH4  -45.6
# 86    AT+NoExp  2050     Power-to-NH3  -37.3
# 87    AT+NoExp  2050  Power-to-liquid -128.0
# 88    AT+NoExp  2050              SMR    3.3

# %% [markdown]
# ## Energy and feedstock market balance | Liquid fuel

# %%
df = prepare_dataframe(balance_dict["oil"], idx_group, set_scen_col)
df = df[df["value"]!=0]
df.variable = df.variable.map(rename_oil)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "liquid_fuel_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["oil"],
    category_orders={
        "variable":list(colors["oil"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"Liquid fuel balance in TWh","year":"",
            "variable":"", 
            "scen":""},

)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_ZA_2030 AT+100%Exp 2030 ZA       338.6
#                             AT+50%Exp  2030 ZA       336.7
#                             AT+NoExp   2030 ZA       334.7
#                 DKS_ZA_2050 AB+100%Exp 2050 ZA       235.5
#                             AB+50%Exp  2050 ZA       222.2
#                             AB+NoExp   2050 ZA       208.8
#                             AT+100%Exp 2050 ZA       172.8
#                             AT+50%Exp  2050 ZA       159.5
#                             AT+NoExp   2050 ZA       146.1
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="c0a365e0-aee3-43a9-b46c-bb54a9d8ecb9" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c0a365e0-aee3-43a9-b46c-bb54a9d8ecb9")) {                    Plotly.newPlot(                        "c0a365e0-aee3-43a9-b46c-bb54a9d8ecb9",                        [{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fossil fuel import","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Fossil fuel import","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZnpdECamZmZmel0QJqZmZmZ6XRA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZnpdECamZmZmel0QJqZmZmZ6XRA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fossil fuel import","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Fossil fuel import","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"mpmZmZmZyb+amZmZmZnJv5qZmZmZmcm\u002fmpmZmZmZyb+amZmZmZnJv5qZmZmZmcm\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"mpmZmZmZyb+amZmZmZnJv5qZmZmZmcm\u002fmpmZmZmZyb+amZmZmZnJv5qZmZmZmcm\u002f"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-liquid","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Power-to-liquid","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzD0AAAAAAAAAAQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzD0AAAAAAAAAAQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-liquid","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Power-to-liquid","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"mpmZmZkZakDNzMzMzExoQGZmZmZmdmZAAAAAAACAX0AAAAAAAOBbQM3MzMzMbFhA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"mpmZmZkZakDNzMzMzExoQGZmZmZmdmZAAAAAAACAX0AAAAAAAOBbQM3MzMzMbFhA"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Land transport","marker":{"color":"#669db2","pattern":{"shape":""}},"name":"Land transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzsZsDNzMzMzOxmwM3MzMzM7GbA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzsZsDNzMzMzOxmwM3MzMzM7GbA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Land transport","marker":{"color":"#669db2","pattern":{"shape":""}},"name":"Land transport","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"ZmZmZmZmR8BmZmZmZmZHwGZmZmZmZkfAZmZmZmZmMsBmZmZmZmYywGZmZmZmZjLA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdat ...

# %% [markdown]
# ## Energy and feedstock market balance | CH4

# %%
df = prepare_dataframe(balance_dict["gas"], idx_group, set_scen_col, rename_function=rename_gas)
df = df[df["value"]!=0]
# df.variable = df.variable.map(rename_gas)

# %%
(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "CH4_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["gas"],
    category_orders={
        "variable":list(colors["gas"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"CH4 balance in TWh","year":"",
            "variable":"", 
            "scen":""},

)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_ZA_2030 AT+100%Exp 2030 ZA        44.0
#                             AT+50%Exp  2030 ZA        44.0
#                             AT+NoExp   2030 ZA        44.0
#                 DKS_ZA_2050 AB+100%Exp 2050 ZA        46.1
#                             AB+50%Exp  2050 ZA        48.1
#                             AB+NoExp   2050 ZA        50.0
#                             AT+100%Exp 2050 ZA        30.0
#                             AT+50%Exp  2050 ZA        33.7
#                             AT+NoExp   2050 ZA        37.4
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="adc9a18f-1efd-4357-a691-0cffecc7cb45" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("adc9a18f-1efd-4357-a691-0cffecc7cb45")) {                    Plotly.newPlot(                        "adc9a18f-1efd-4357-a691-0cffecc7cb45",                        [{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-CH4","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Power-to-CH4","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZlZRkDNzMzMzExHQJqZmZmZWUhAmpmZmZmZPEBmZmZmZiZAQDMzMzMz80FA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"mpmZmZlZRkDNzMzMzExHQJqZmZmZWUhAmpmZmZmZPEBmZmZmZiZAQDMzMzMz80FA"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commerce","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Commerce","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz078zMzMzMzPTvzMzMzMzM9O\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz078zMzMzMzPTvzMzMzMzM9O\u002f"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commerce","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Commerce","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"MzMzMzMz078zMzMzMzPTvzMzMzMzM9O\u002fMzMzMzMz078zMzMzMzPTvzMzMzMzM9O\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"MzMzMzMz078zMzMzMzPTvzMzMzMzM9O\u002fMzMzMzMz078zMzMzMzPTvzMzMzMzM9O\u002f"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas import","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Gas import","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAARkAAAAAAAABGQAAAAAAAAEZA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAARkAAAAAAAABGQAAAAAAAAEZA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmJcBmZmZmZmYowDMzMzMzMyvAMzMzMzOzMsDNzMzMzEw1wDMzMzMzszfA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"ZmZmZmZmJcBmZmZmZmYowDMzMzMzMyvAMzMzMzOzMsDNzMzMzEw1wDMzMzMzszfA"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMQMDNzMzMzMxAwM3MzMzMzEDA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMQMDNzMzMzMxAwM3MzMzMzEDA"},"yaxis":"y"," ...

# %%
df
# Out:
#    run_name_prefix     run_name        scen  year country          variable  \
# 1              DKS  DKS_ZA_2030  AT+100%Exp  2030      ZA          Commerce
# 3              DKS  DKS_ZA_2030  AT+100%Exp  2030      ZA        Gas import
# 5              DKS  DKS_ZA_2030  AT+100%Exp  2030      ZA          Industry
# 8              DKS  DKS_ZA_2030  AT+100%Exp  2030      ZA               SMR
# 10             DKS  DKS_ZA_2030   AT+50%Exp  2030      ZA          Commerce
# 12             DKS  DKS_ZA_2030   AT+50%Exp  2030      ZA        Gas import
# 14             DKS  DKS_ZA_2030   AT+50%Exp  2030      ZA          Industry
# 17             DKS  DKS_ZA_2030   AT+50%Exp  2030      ZA               SMR
# 19             DKS  DKS_ZA_2030    AT+NoExp  2030      ZA          Commerce
# 21             DKS  DKS_ZA_2030    AT+NoExp  2030      ZA        Gas import
# 23             DKS  DKS_ZA_2030    AT+NoExp  2030      ZA          Industry
# 26             DKS  DKS_ZA_2030    AT+NoExp  2030      ZA               SMR
# 27             DKS  DKS_ZA_2050  AB+100%Exp  2050      ZA            Biogas
# 28             DKS  DKS_ZA_2050  AB+100%Exp  2050      ZA          Commerce
# 31             DKS  DKS_ZA_2050  AB+100%Exp  2050      ZA      Gas turbines
# 33             DKS  DKS_ZA_2050  AB+100%Exp  2050      ZA  Industry with CC
# 34             DKS  DKS_ZA_2050  AB+100%Exp  2050      ZA      Power-to-CH4
# 35             DKS  DKS_ZA_2050  AB+100%Exp  2050      ZA               SMR
# 36             DKS  DKS_ZA_2050   AB+50%Exp  2050      ZA            Biogas
# 37             DKS  DKS_ZA_2050   AB+50%Exp  2050      ZA          Commerce
# 40             DKS  DKS_ZA_2050   AB+50%Exp  2050      ZA      Gas turbines
# 42             DKS  DKS_ZA_2050   AB+50%Exp  2050      ZA  Industry with CC
# 43             DKS  DKS_ZA_2050   AB+50%Exp  2050      ZA      Power-to-CH4
# 44             DKS  DKS_ZA_2050   AB+50%Exp  2050      ZA               SMR
# 45             DKS  DKS_ZA_2050    AB+NoExp  2050      ZA            Biogas
# 46             DKS  DKS_ZA_2050    AB+NoExp  2050      ZA          Commerce
# 49             DKS  DKS_ZA_2050    AB+NoExp  2050      ZA      Gas turbines
# 51             DKS  DKS_ZA_2050    AB+NoExp  2050      ZA  Industry with CC
# 52             DKS  DKS_ZA_2050    AB+NoExp  2050      ZA      Power-to-CH4
# 53             DKS  DKS_ZA_2050    AB+NoExp  2050      ZA               SMR
# 54             DKS  DKS_ZA_2050  AT+100%Exp  2050      ZA            Biogas
# 55             DKS  DKS_ZA_2050  AT+100%Exp  2050      ZA          Commerce
# 58             DKS  DKS_ZA_2050  AT+100%Exp  2050      ZA      Gas turbines
# 60             DKS  DKS_ZA_2050  AT+100%Exp  2050      ZA  Industry with CC
# 61             DKS  DKS_ZA_2050  AT+100%Exp  2050      ZA      Power-to-CH4
# 62             DKS  DKS_ZA_2050  AT+100%Exp  2050      ZA               SMR
# 63             DKS  DKS_ZA_2050   AT+50%Exp  2050      ZA            Biogas
# 64             DKS  DKS_ZA_2050   AT+50%Exp  2050      ZA          Commerce
# 67             DKS  DKS_ZA_2050   AT+50%Exp  2050      ZA      Gas turbines
# 69             DKS  DKS_ZA_2050   AT+50%Exp  2050      ZA  Industry with CC
# 70             DKS  DKS_ZA_2050   AT+50%Exp  2050      ZA      Power-to-CH4
# 71             DKS  DKS_ZA_2050   AT+50%Exp  2050      ZA               SMR
# 72             DKS  DKS_ZA_2050    AT+NoExp  2050      ZA            Biogas
# 73             DKS  DKS_ZA_2050    AT+NoExp  2050      ZA          Commerce
# 76             DKS  DKS_ZA_2050    AT+NoExp  2050      ZA      Gas turbines
# 78             DKS  DKS_ZA_2050    AT+NoExp  2050      ZA  Industry with CC
# 79             DKS  DKS_ZA_2050    AT+NoExp  2050      ZA      Power-to-CH4
# 80             DKS  DKS_ZA_2050    AT+NoExp  2050      ZA               SMR
#
#     value
# 1    -0.3
# 3    44.0
# 5   -33.6
# 8   -10.1
# 10   -0.3
# 12   44.0
# 14  -33.6
# 17  -10.1
# 19   -0.3
# 21   44.0
# 23  -33.6
# 26  -10.1
# 27    1.4
# 28   -0.3
# 31  -10.7
# 33  -34.5
# 34   44.7
# 35   -0.6
# 36    1.4
# 37   -0.3
# 40  -12.2
# 42  -34.5
# 43   46.6
# 44   -1.1
# 45    1.4
# 46   -0.3
# 49  -13.6
# 51  -34.5
# 52   48.7
# 53   -1.6
# 54    1.4
# 55   -0.3
# 58  -18.7
# 60   -9.0
# 61   28.6
# 62   -2.0
# 63    1.4
# 64   -0.3
# 67  -21.3
# 69   -9.0
# 70   32.3
# 71   -3.1
# 72    1.4
# 73   -0.3
# 76  -23.7
# 78   -9.0
# 79   35.9
# 80   -4.4

# %% [markdown]
# ## Energy and feedstock market balance | CO2

# %%
df = prepare_dataframe(balance_dict["co2 stored"], idx_group, set_scen_col)
df = df[df["value"]!=0]

df.variable = df.variable.map(rename_co2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["co2"],
    category_orders={
        "variable":list(colors["gas"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"CO<sub>2</sub> Capture (+) and Usage (-) in Mt","year":"","variable":"", "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_CO2_capture_and_usage_Mt")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_ZA_2030 AT+100%Exp 2030 ZA         1.0
#                             AT+50%Exp  2030 ZA         0.5
#                 DKS_ZA_2050 AB+100%Exp 2050 ZA       117.0
#                             AB+50%Exp  2050 ZA       113.6
#                             AB+NoExp   2050 ZA       110.1
#                             AT+100%Exp 2050 ZA        81.0
#                             AT+50%Exp  2050 ZA        77.7
#                             AT+NoExp   2050 ZA        74.5
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="73c8e070-a2f9-4d31-ae9b-9e7de2e6a2a7" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("73c8e070-a2f9-4d31-ae9b-9e7de2e6a2a7")) {                    Plotly.newPlot(                        "73c8e070-a2f9-4d31-ae9b-9e7de2e6a2a7",                        [{"hovertemplate":"=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-CH4","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Power-to-CH4","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAIsDNzMzMzMwiwJqZmZmZmSPAMzMzMzMzF8AAAAAAAAAawM3MzMzMzBzA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAAIsDNzMzMzMwiwJqZmZmZmSPAMzMzMzMzF8AAAAAAAAAawM3MzMzMzBzA"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-liquid","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Power-to-liquid","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA8L8AAAAAAADgvw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA8L8AAAAAAADgvw=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-liquid","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Power-to-liquid","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"zczMzMzMS8BmZmZmZuZJwDMzMzMz80fAzczMzMzMQMAzMzMzM7M9wAAAAAAAADrA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"zczMzMzMS8BmZmZmZuZJwDMzMzMz80fAzczMzMzMQMAzMzMzM7M9wAAAAAAAADrA"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Process emissions with CC","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Process emissions with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA8D8AAAAAAADgPw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA8D8AAAAAAADgPw=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Process emissions with CC","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Process emissions with CC","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"AAAAAAAATEAAAAAAAABMQAAAAAAAAExAAAAAAAAATEAAAAAAAABMQAAAAAAAAExA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAATEAAAAAAAABMQAAAAAAAAExAAAAAAAAATEAAAAAAAABMQAAAAAAAAExA"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Direct air capture","marker":{"color":"#7 ...

# %% [markdown]
# ## CO2 atmosphere balance

# %%
df = prepare_dataframe(balance_dict["co2"], idx_group, set_scen_col)

df.variable = df.variable.map(rename_co2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "co2_emissions_mt"
fig = px.bar(
    df, 
    **fig_kwargs,
    labels={"value":"CO2 emissions in Mt<sub>CO2</sub>",
            "year":"",
            "variable":"", 
            "scen":""
            },
    color_discrete_map=colors["co2"],
    category_orders={
        "variable":list(colors["co2"].keys()),
        "scen": scen_order
        },
    #facet_col_wrap=1, facet_col_spacing=0.07,
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(supply_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_ZA_2030 AT+100%Exp 2030 ZA       233.8
#                             AT+50%Exp  2030 ZA       233.9
#                             AT+NoExp   2030 ZA       233.9
#                 DKS_ZA_2050 AB+100%Exp 2050 ZA        81.3
#                             AB+50%Exp  2050 ZA        78.3
#                             AB+NoExp   2050 ZA        75.1
#                             AT+100%Exp 2050 ZA        55.7
#                             AT+50%Exp  2050 ZA        52.7
#                             AT+NoExp   2050 ZA        49.7
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="44ec233e-c4b6-4e12-9ffe-6a68771fe30e" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("44ec233e-c4b6-4e12-9ffe-6a68771fe30e")) {                    Plotly.newPlot(                        "44ec233e-c4b6-4e12-9ffe-6a68771fe30e",                        [{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Process emissions with CC","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Process emissions with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT+amZmZmZm5Pw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT+amZmZmZm5Pw=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Process emissions with CC","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Process emissions with CC","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"MzMzMzMzB0AzMzMzMzMHQDMzMzMzMwdAMzMzMzMzB0AzMzMzMzMHQDMzMzMzMwdA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"MzMzMzMzB0AzMzMzMzMHQDMzMzMzMwdAMzMzMzMzB0AzMzMzMzMHQDMzMzMzMwdA"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biomass for industry with CC","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Biomass for industry with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZHcCamZmZmZkdwJqZmZmZmR3AmpmZmZmZAcCamZmZmZkBwJqZmZmZmQHA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"mpmZmZmZHcCamZmZmZkdwJqZmZmZmR3AmpmZmZmZAcCamZmZmZkBwJqZmZmZmQHA"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biomass for CHP with CC","marker":{"color":"#C2D05C","pattern":{"shape":""}},"name":"Biomass for CHP with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAJ8BmZmZmZmYlwDMzMzMzMyPAzczMzMzMFsCamZmZmZkTwAAAAAAAABDA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAAJ8BmZmZmZmYlwDMzMzMzMyPAzczMzMzMFsCamZmZmZkTwAAAAAAAABDA"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas for industry with CC","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Gas for industry with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz0z8zMzMzMzPTPzMzMzMzM9M\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"MzMzMzMz0z8zMzMzMzPTPzMzMzMzM9M\u002fmpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002f"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub ...

# %%
1e4
# Out:
# 10000.0

# %% [markdown]
# # Installed Capacity

# %%
df = prepare_dataframe(optimal_capacity_dict["AC"], idx_group, set_scen_col, rename_function=rename_electricity)
df = df[df["value"]<4000] #drop loadshedding capacity
df = df.query("scen in @scen_filter")
df.variable = df.variable.map(rename_to_upper_case)
df = df[~((df["variable"] == "Coal") & (df["year"] == 2050))]
(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "electricity_installed_capacity_GW"
fig = px.bar(
    df, 
    **fig_kwargs,
    #barmode="stack",
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    #range_y=(0,supply_sum_df.max().value*1.1),
    labels={"value":"Installed capacity in GW<sub>el</sub>","year":"",
            "variable":"",
            "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_ZA_2030 AT+100%Exp 2030 ZA       127.3
#                             AT+50%Exp  2030 ZA       119.5
#                             AT+NoExp   2030 ZA       111.9
#                 DKS_ZA_2050 AB+50%Exp  2050 ZA       527.1
#                             AT+100%Exp 2050 ZA       483.5
#                             AT+50%Exp  2050 ZA       465.7
#                             AT+NoExp   2050 ZA       448.9
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="26a358dc-28ef-4bde-9e1f-815594bd28d2" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("26a358dc-28ef-4bde-9e1f-815594bd28d2")) {                    Plotly.newPlot(                        "26a358dc-28ef-4bde-9e1f-815594bd28d2",                        [{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAABAQUCamZmZmRlAQAAAAAAAAD5A"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAABAQUCamZmZmRlAQAAAAAAAAD5A"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"AAAAAACQcEDNzMzMzAxuQDMzMzMz42xAAAAAAACwa0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAACQcEDNzMzMzAxuQDMzMzMz42xAAAAAAACwa0A="},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZnZSkCamZmZmRlIQGZmZmZmZkVA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZnZSkCamZmZmRlIQGZmZmZmZkVA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"zczMzMycbUDNzMzMzLxqQM3MzMzMbGlAAAAAAABAaEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"zczMzMycbUDNzMzMzLxqQM3MzMzMbGlAAAAAAABAaEA="},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coal","marker":{"color":"#454545","pattern":{"shape":""}},"name":"Coal","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZQECamZmZmZlAQJqZmZmZmUBA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZQECamZmZmZlAQJqZmZmZmUBA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAADEAAAAAAAAAMQAAAAAAAAAxA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAADEAAAAAAAAAMQAAAAAAAAAxA"},"yaxis":"y","type":"bar"," ...

# %%
df[["scen", "year", "variable", "value"]]
# Out:
#           scen  year      variable  value
# 1   AT+100%Exp  2030          Coal   33.2
# 4   AT+100%Exp  2030         Hydro    3.5
# 5   AT+100%Exp  2030       Nuclear    2.0
# 6   AT+100%Exp  2030      Solar PV   34.5
# 9   AT+100%Exp  2030           Oil    0.4
# 10  AT+100%Exp  2030  Wind onshore   53.7
# 12   AT+50%Exp  2030          Coal   33.2
# 15   AT+50%Exp  2030         Hydro    3.5
# 16   AT+50%Exp  2030       Nuclear    2.0
# 17   AT+50%Exp  2030      Solar PV   32.2
# 20   AT+50%Exp  2030           Oil    0.4
# 21   AT+50%Exp  2030  Wind onshore   48.2
# 23    AT+NoExp  2030          Coal   33.2
# 26    AT+NoExp  2030         Hydro    3.5
# 27    AT+NoExp  2030       Nuclear    2.0
# 28    AT+NoExp  2030      Solar PV   30.0
# 31    AT+NoExp  2030           Oil    0.4
# 32    AT+NoExp  2030  Wind onshore   42.8
# 44   AB+50%Exp  2050       Battery    7.3
# 46   AB+50%Exp  2050  Gas turbines   11.8
# 48   AB+50%Exp  2050         Hydro    3.7
# 49   AB+50%Exp  2050       Nuclear    2.0
# 50   AB+50%Exp  2050      Solar PV  265.0
# 53   AB+50%Exp  2050           Oil    0.4
# 54   AB+50%Exp  2050  Wind onshore  236.9
# 66  AT+100%Exp  2050       Battery    7.6
# 68  AT+100%Exp  2050  Gas turbines   15.5
# 70  AT+100%Exp  2050         Hydro    3.7
# 71  AT+100%Exp  2050       Nuclear    2.0
# 72  AT+100%Exp  2050      Solar PV  240.4
# 75  AT+100%Exp  2050           Oil    0.4
# 76  AT+100%Exp  2050  Wind onshore  213.9
# 77   AT+50%Exp  2050       Battery    7.9
# 79   AT+50%Exp  2050  Gas turbines   17.2
# 81   AT+50%Exp  2050         Hydro    3.7
# 82   AT+50%Exp  2050       Nuclear    2.0
# 83   AT+50%Exp  2050      Solar PV  231.1
# 86   AT+50%Exp  2050           Oil    0.4
# 87   AT+50%Exp  2050  Wind onshore  203.4
# 88    AT+NoExp  2050       Battery    8.5
# 90    AT+NoExp  2050  Gas turbines   18.8
# 92    AT+NoExp  2050         Hydro    3.7
# 93    AT+NoExp  2050       Nuclear    2.0
# 94    AT+NoExp  2050      Solar PV  221.5
# 97    AT+NoExp  2050           Oil    0.4
# 98    AT+NoExp  2050  Wind onshore  194.0

# %%
df = prepare_dataframe(optimal_capacity_dict["H2"], idx_group, set_scen_col, rename_function=rename_h2)
df = df[df["value"]<4000] #drop loadshedding capacity
df = df.query("scen in @scen_filter")

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "hydrogen_installed_capacity_GW"
fig_kwargs_mod = fig_kwargs.copy()
fig_kwargs_mod["height"] = heights["2"]
fig = px.bar(
    df, 
    **fig_kwargs_mod,
    color_discrete_map={"H2 Electrolysis":"#179c7d"},
    category_orders={
        #"variable":list(colors["gas"].keys())
        "scen": scen_order
        },
    labels={"value":"Installed capacity in GW<sub>H2</sub>","year":"","variable":"","scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_ZA_2030 AT+100%Exp 2030 ZA         3.9
#                             AT+50%Exp  2030 ZA         2.4
#                             AT+NoExp   2030 ZA         0.9
#                 DKS_ZA_2050 AB+50%Exp  2050 ZA        73.7
#                             AT+100%Exp 2050 ZA        59.7
#                             AT+50%Exp  2050 ZA        55.2
#                             AT+NoExp   2050 ZA        50.8
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="deba4bf4-57d5-43aa-b14a-747f5f1c0001" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("deba4bf4-57d5-43aa-b14a-747f5f1c0001")) {                    Plotly.newPlot(                        "deba4bf4-57d5-43aa-b14a-747f5f1c0001",                        [{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAACEAAAAAAAAD4Pw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAACEAAAAAAAAD4Pw=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"AAAAAAAAUkCamZmZmZlMQDMzMzMz80lAmpmZmZlZR0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"AAAAAAAAUkCamZmZmZlMQDMzMzMz80lAmpmZmZlZR0A="},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"SMR","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM7D\u002fNzMzMzMzsP83MzMzMzOw\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM7D\u002fNzMzMzMzsP83MzMzMzOw\u002f"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"SMR","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"MzMzMzMz+z8AAAAAAAAEQGZmZmZmZgpAZmZmZmZmEEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+50%Exp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"MzMzMzMz+z8AAAAAAAAEQGZmZmZmZgpAZmZmZmZmEEA="},"yaxis":"y2","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.222222222222 ...

# %%
print(df[["scen", "year", "variable", "value"]])
# Out:
#           scen  year         variable  value
# 0   AT+100%Exp  2030  H2 Electrolysis    3.0
# 1   AT+100%Exp  2030              SMR    0.9
# 3    AT+50%Exp  2030  H2 Electrolysis    1.5
# 4    AT+50%Exp  2030              SMR    0.9
# 7     AT+NoExp  2030              SMR    0.9
# 12   AB+50%Exp  2050  H2 Electrolysis   72.0
# 13   AB+50%Exp  2050              SMR    1.7
# 18  AT+100%Exp  2050  H2 Electrolysis   57.2
# 19  AT+100%Exp  2050              SMR    2.5
# 21   AT+50%Exp  2050  H2 Electrolysis   51.9
# 22   AT+50%Exp  2050              SMR    3.3
# 24    AT+NoExp  2050  H2 Electrolysis   46.7
# 25    AT+NoExp  2050              SMR    4.1

# %%
stats_df = pd.concat([costs_dict["capex"],costs_dict["opex"]],axis=0)
df = prepare_dataframe(stats_df, idx_group, set_scen_col)
df.variable = df.variable.map(rename_costs) # ToDo rename important cost components
df = df.groupby(["run_name_prefix", "scen", "year", "country", "variable"], as_index=False).sum().round(1)
df = df[df["value"]!=0]

# (supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df, threshold=0., round=1)

# %%
fig_name = "system_costs_billion_eur" # expenditure and export revenue
fig_kwargs["height"] = heights["3"]
fig_kwargs["text_auto"] = ".1f"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["costs"],
    category_orders={
        "variable":list(colors["costs"].keys()),
        #"scen": scen_order
        },
    facet_col_spacing=0.1,
    labels={"value":"System costs in billion EUR20XX/year","year":"", 
            #"variable":"", 
            "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_installed_capacity_AC_GW")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_ZA_2030 AT+100%Exp 2030 ZA         3.9
#                             AT+50%Exp  2030 ZA         2.4
#                             AT+NoExp   2030 ZA         0.9
#                 DKS_ZA_2050 AB+50%Exp  2050 ZA        73.7
#                             AT+100%Exp 2050 ZA        59.7
#                             AT+50%Exp  2050 ZA        55.2
#                             AT+NoExp   2050 ZA        50.8
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="7c72c648-04b8-420a-a134-c8c0788c751e" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7c72c648-04b8-420a-a134-c8c0788c751e")) {                    Plotly.newPlot(                        "7c72c648-04b8-420a-a134-c8c0788c751e",                        [{"hovertemplate":"variable=Solar\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmKECamZmZmZknQJqZmZmZmSZAZmZmZmZmJUCamZmZmZkkQJqZmZmZmSNA"},"textposition":"inside","texttemplate":"%{y:.1f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmKECamZmZmZknQJqZmZmZmSZAZmZmZmZmJUCamZmZmZkkQJqZmZmZmSNA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Solar\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"mpmZmZmZAUDNzMzMzMwAQGZmZmZmZv4\u002f"},"textposition":"inside","texttemplate":"%{y:.1f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"mpmZmZmZAUDNzMzMzMwAQGZmZmZmZv4\u002f"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"variable=Wind\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzREAAAAAAAEBDQGZmZmZmZkJAmpmZmZlZQUAAAAAAAIBAQAAAAAAAgD9A"},"textposition":"inside","texttemplate":"%{y:.1f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzREAAAAAAAEBDQGZmZmZmZkJAmpmZmZlZQUAAAAAAAIBAQAAAAAAAgD9A"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Wind\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind","orientation":"v","showlegend":false,"text":{"dtype":"f8","bdata":"ZmZmZmZmI0BmZmZmZmYhQDMzMzMzMx9A"},"textposition":"inside","texttemplate":"%{y:.1f}","x":["AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x2","y":{"dtype":"f8","bdata":"ZmZmZmZmI0BmZmZmZmYhQDMzMzMzMx9A"},"yaxis":"y2","type":"bar","textangle":0},{"hovertemplate":"variable=H2 Electrolysis\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAJECamZmZmZkiQDMzMzMzMyFAmpmZmZmZHUDNzMzMzMwaQGZmZmZmZhhA"},"textposition":"inside","texttemplate":"%{y:.1f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAJECamZmZmZkiQDMzMzMzMyFAmpmZmZmZHUDNzMzMzMwaQGZmZmZmZhhA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=H2 Electrolysis\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysi ...

# %% [markdown]
# ## Relative costs
#
# costs / total energy consumption

# %% [markdown]
# ## Water consumption
