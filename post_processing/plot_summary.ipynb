# %% [markdown]
# Plot the summary of statistics (energy balance, optimal capacity, ...)
#
# **Prerequisites**
#
# * Execute "make_stats_dict.py" before using this notebook. The script make_stats_dict creates csv for the metrics for all runs of multiple config files.
# * Install the environment envs/pypsa-earth-vis.yaml

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import pandas as pd
idx_slice = pd.IndexSlice
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # Comment out for debugging and development
warnings.simplefilter(action='ignore', category=DeprecationWarning) # Comment out for debugging and development
import plotly.express as px

from plot_helpers import (
    chdir_to_parent_dir,
    read_stats_dict,
    drop_index_levels, 
    update_layout, 
    prepare_dataframe,
    get_supply_demand_from_balance,
    rename_electricity, 
    rename_h2,
    rename_gas,
    rename_oil,
    rename_co2,
    rename_costs,
    rename_to_upper_case,
    colors,
    nice_title,
    save_plotly_fig)

chdir_to_parent_dir()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
run_name_prefix = "DKS" # Experiment name

sdir = Path.cwd() / "results"/ f"{run_name_prefix}_summary"
sdir.mkdir(exist_ok=True, parents=True)

# %%
balance_dict = read_stats_dict("balance_dict", sdir, keys=["AC", "H2", "oil", "gas", "co2 stored", "co2"])
optimal_capacity_dict = read_stats_dict("optimal_capacity_dict", sdir, keys=["AC", "H2"])
costs_dict = read_stats_dict("costs_dict", sdir, keys=["capex", "opex"])

# simplify index for plotting: define a scen_str column and drop all other columns
#NB: the following is specific to the experiment

index_levels_to_drop=["simpl", "clusters", "ll", "opts", "discountrate", "demand"] #, "sopts"


for key in balance_dict.keys():
    balance_dict[key] = drop_index_levels(balance_dict[key], to_drop=index_levels_to_drop)

for key in optimal_capacity_dict.keys():
    optimal_capacity_dict[key] = drop_index_levels(optimal_capacity_dict[key], to_drop=index_levels_to_drop)
    
for key in costs_dict.keys():
    costs_dict[key] = drop_index_levels(costs_dict[key], to_drop=index_levels_to_drop)
# Out:
# Imported AC from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKS_summary\balance_dict_AC.csv
# Imported H2 from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKS_summary\balance_dict_H2.csv
# Imported oil from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKS_summary\balance_dict_oil.csv
# Imported gas from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKS_summary\balance_dict_gas.csv
# Imported co2 stored from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKS_summary\balance_dict_co2 stored.csv
# Imported co2 from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKS_summary\balance_dict_co2.csv
# Imported AC from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKS_summary\optimal_capacity_dict_AC.csv
# Imported H2 from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKS_summary\optimal_capacity_dict_H2.csv
# Imported capex from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKS_summary\costs_dict_capex.csv
# Imported opex from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKS_summary\costs_dict_opex.csv

# %%
def set_scen_col(df):
    """
    Set combined scenario str (for plots).
    NB: This is specific to the experiment and should be adapted for other experiments.
    """
    df = df.copy()
    
    df["scen"] = df["eopts"] + "+" + df["sopts"]
    df = df.drop(columns=["eopts", "sopts"])
    #df["scen"] = df.apply(lambda row: "_".join([f"{col}_{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)
    #df["scen"] = df.apply(lambda row: "_".join([f"{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)

    return df

# %% [markdown]
# # Plotting

# %%
print(balance_dict["AC"].index.names)
print(balance_dict["AC"].index)
# Out:
# ['run_name_prefix', 'run_name', 'country', 'year', 'sopts', 'eopts']
# MultiIndex([('DKS', 'DKS_EG_2050_eopts', 'EG', 2050, '3H', ...),
#             ('DKS', 'DKS_EG_2050_eopts', 'EG', 2050, '3H', ...),
#             ('DKS', 'DKS_EG_2050_eopts', 'EG', 2050, '3H', ...),
#             ('DKS', 'DKS_EG_2050_eopts', 'EG', 2050, '3H', ...),
#             ('DKS', 'DKS_EG_2050_eopts', 'EG', 2050, '3H', ...)],
#            names=['run_name_prefix', 'run_name', 'country', 'year', 'sopts', 'eopts'])

# %%
width = 700
heights = {"1": 300,"2": 600,"3": 700,}

fig_kwargs = dict(
    x="scen", 
    y="value", 
    color="variable", 
    facet_col="year", 
    facet_row="run_name",
    barmode="relative", 
    text="value", 
    #facet_col_wrap=1, facet_col_spacing=0.07,
    width=width, 
    height=heights["2"],
    text_auto =".0f",
)

scen_order = [] # option to specify order of scenarios in the plot

# %%
# balance_dict["gas"].query("year == 2050 and country == 'ZA'").T

# %%
# balance_dict["co2 stored"].query("year == 2050 and country == 'ZA'").T

# %%
# select and define index group (multiindex) for plots: which solutions to show at once

idx_group = idx_slice[["DKS"],:,["EG"],[2050],["3H"]]
idx_group_name = ""

print(idx_group_name) 
print(idx_group)
# Out:
# (['DKS'], slice(None, None, None), ['EG'], [2050], ['3H'])

# %% [markdown]
# ## Energy market balance | Electricity

# %%
balance_dict["AC"]
# Out:
#                                                                                   AC  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0            -310.7
#                                                      H2m1.0+H2v0.5            -310.7
#                                                      H2m1.0+NH3v1.0           -310.7
#                                                      H2m1.0+NH3v1.0+FTv1.0    -310.7
#                                                      H2v1.01+NH3v1.01+FTv1.01 -310.7
#
#                                                                                BEV charger  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                   -16.8
#                                                      H2m1.0+H2v0.5                   -16.8
#                                                      H2m1.0+NH3v1.0                  -16.8
#                                                      H2m1.0+NH3v1.0+FTv1.0           -16.8
#                                                      H2v1.01+NH3v1.01+FTv1.01        -16.8
#
#                                                                                CCGT  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0              2.7
#                                                      H2m1.0+H2v0.5              2.7
#                                                      H2m1.0+NH3v1.0             2.7
#                                                      H2m1.0+NH3v1.0+FTv1.0      2.8
#                                                      H2v1.01+NH3v1.01+FTv1.01   0.7
#
#                                                                                  DAC  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0              -2.7
#                                                      H2m1.0+H2v0.5              -2.7
#                                                      H2m1.0+NH3v1.0             -2.7
#                                                      H2m1.0+NH3v1.0+FTv1.0      -3.6
#                                                      H2v1.01+NH3v1.01+FTv1.01 -941.7
#
#                                                                                Fischer-Tropsch  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                        -1.2
#                                                      H2m1.0+H2v0.5                        -1.2
#                                                      H2m1.0+NH3v1.0                       -1.2
#                                                      H2m1.0+NH3v1.0+FTv1.0                -1.3
#                                                      H2v1.01+NH3v1.01+FTv1.01            -63.7
#
#                                                                                H2 Electrolysis  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                      -935.4
#                                                      H2m1.0+H2v0.5                      -847.5
#                                                      H2m1.0+NH3v1.0                     -952.6
#                                                      H2m1.0+NH3v1.0+FTv1.0              -971.1
#                                                      H2v1.01+NH3v1.01+FTv1.01         -17152.3
#
#                                                                                H2 Fuel Cell  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                      0.0
#                                                      H2m1.0+H2v0.5                      0.0
#                                                      H2m1.0+NH3v1.0                     0.0
#                                                      H2m1.0+NH3v1.0+FTv1.0              0.0
#                                                      H2v1.01+NH3v1.01+FTv1.01           0.0
#
#                                                                                Haber-Bosch  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                    -0.0
#                                                      H2m1.0+H2v0.5                    -0.0
#                                                      H2m1.0+NH3v1.0                   -1.3
#                                                      H2m1.0+NH3v1.0+FTv1.0            -1.3
#                                                      H2v1.01+NH3v1.01+FTv1.01         -0.0
#
#                                                                                OCGT  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0              0.0
#                                                      H2m1.0+H2v0.5              0.0
#                                                      H2m1.0+NH3v1.0             0.0
#                                                      H2m1.0+NH3v1.0+FTv1.0      0.0
#                                                      H2v1.01+NH3v1.01+FTv1.01   0.0
#
#                                                                                PHS  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0            -0.0
#                                                      H2m1.0+H2v0.5            -0.0
#                                                      H2m1.0+NH3v1.0           -0.0
#                                                      H2m1.0+NH3v1.0+FTv1.0    -0.0
#                                                      H2v1.01+NH3v1.01+FTv1.01 -0.0
#
#                                                                                ...  \
# run_name_prefix run_name          country year sopts eopts                     ...
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0             ...
#                                                      H2m1.0+H2v0.5             ...
#                                                      H2m1.0+NH3v1.0            ...
#                                                      H2m1.0+NH3v1.0+FTv1.0     ...
#                                                      H2v1.01+NH3v1.01+FTv1.01  ...
#
#                                                                                services rural resistive heater  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                                        -0.0
#                                                      H2m1.0+H2v0.5                                        -0.0
#                                                      H2m1.0+NH3v1.0                                       -0.0
#                                                      H2m1.0+NH3v1.0+FTv1.0                                -0.0
#                                                      H2v1.01+NH3v1.01+FTv1.01                             -0.0
#
#                                                                                services urban decentral air heat pump  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                                               -0.0
#                                                      H2m1.0+H2v0.5                                               -0.0
#                                                      H2m1.0+NH3v1.0                                              -0.0
#                                                      H2m1.0+NH3v1.0+FTv1.0                                       -0.0
#                                                      H2v1.01+NH3v1.01+FTv1.01                                    -0.0
#
#                                                                                services urban decentral resistive heater  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                                                  -0.0
#                                                      H2m1.0+H2v0.5                                                  -0.0
#                                                      H2m1.0+NH3v1.0                                                 -0.0
#                                                      H2m1.0+NH3v1.0+FTv1.0                                          -0.0
#                                                      H2v1.01+NH3v1.01+FTv1.01                                       -0.0
#
#                                                                                  solar  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0               755.5
#                                                      H2m1.0+H2v0.5               691.7
#                                                      H2m1.0+NH3v1.0              763.4
#                                                      H2m1.0+NH3v1.0+FTv1.0       775.0
#                                                      H2v1.01+NH3v1.01+FTv1.01  12751.5
#
#                                                                                urban central air heat pump  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                                    -0.0
#                                                      H2m1.0+H2v0.5                                    -0.0
#                                                      H2m1.0+NH3v1.0                                   -0.0
#                                                      H2m1.0+NH3v1.0+FTv1.0                            -0.0
#                                                      H2v1.01+NH3v1.01+FTv1.01                        -10.2
#
#                                                                                urban central gas CHP  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                               0.0
#                                                      H2m1.0+H2v0.5                               0.0
#                                                      H2m1.0+NH3v1.0                              0.0
#                                                      H2m1.0+NH3v1.0+FTv1.0                       0.0
#                                                      H2v1.01+NH3v1.01+FTv1.01                    0.0
#
#                                                                                urban central gas CHP CC  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                                  0.0
#                                                      H2m1.0+H2v0.5                                  0.0
#                                                      H2m1.0+NH3v1.0                                 0.0
#                                                      H2m1.0+NH3v1.0+FTv1.0                          0.0
#                                                      H2v1.01+NH3v1.01+FTv1.01                       0.0
#
#                                                                                urban central resistive heater  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                                       -0.4
#                                                      H2m1.0+H2v0.5                                       -0.4
#                                                      H2m1.0+NH3v1.0                                      -0.4
#                                                      H2m1.0+NH3v1.0+FTv1.0                               -0.4
#                                                      H2v1.01+NH3v1.01+FTv1.01                           -32.9
#
#                                                                                urban central solid biomass CHP  \
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                                         0.0
#                                                      H2m1.0+H2v0.5                                         0.0
#                                                      H2m1.0+NH3v1.0                                        0.0
#                                                      H2m1.0+NH3v1.0+FTv1.0                                 0.0
#                                                      H2v1.01+NH3v1.01+FTv1.01                              0.0
#
#                                                                                urban central solid biomass CHP CC
# run_name_prefix run_name          country year sopts eopts
# DKS             DKS_EG_2050_eopts EG      2050 3H    H2m1.0+H2v1.0                                            6.9
#                                                      H2m1.0+H2v0.5                                            7.0
#                                                      H2m1.0+NH3v1.0                                           6.9
#                                                      H2m1.0+NH3v1.0+FTv1.0                                    7.3
#                                                      H2v1.01+NH3v1.01+FTv1.01                                16.1
#
# [5 rows x 38 columns]

# %%
df = prepare_dataframe(balance_dict["AC"], idx_group, set_scen_col)
df.variable = df.variable.map(rename_electricity).map(rename_to_upper_case)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
supply_df
# Out:
#    run_name_prefix           run_name                         scen  year  \
# 0              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 1              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 2              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 3              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 4              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 5              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 6              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 7              DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 8              DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 9              DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 10             DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 11             DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 12             DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 13             DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 14             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 15             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 16             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 17             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 18             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 19             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 20             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 21             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 22             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 23             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 24             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 25             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 26             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 27             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 28             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 29             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 30             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 31             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 32             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 33             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 34             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
#
#    country      variable    value
# 0       EG       Battery     63.2
# 1       EG           CHP      7.0
# 2       EG  Gas turbines      2.7
# 3       EG         Hydro      7.7
# 4       EG       Nuclear     34.4
# 5       EG      Solar PV    691.7
# 6       EG  Wind onshore    691.4
# 7       EG       Battery     63.8
# 8       EG           CHP      6.9
# 9       EG  Gas turbines      2.7
# 10      EG         Hydro      7.7
# 11      EG       Nuclear     34.6
# 12      EG      Solar PV    755.5
# 13      EG  Wind onshore    715.4
# 14      EG       Battery     63.3
# 15      EG           CHP      6.9
# 16      EG  Gas turbines      2.7
# 17      EG         Hydro      7.7
# 18      EG       Nuclear     34.6
# 19      EG      Solar PV    763.4
# 20      EG  Wind onshore    725.8
# 21      EG       Battery     62.4
# 22      EG           CHP      7.3
# 23      EG  Gas turbines      2.8
# 24      EG         Hydro      7.7
# 25      EG       Nuclear     34.6
# 26      EG      Solar PV    775.0
# 27      EG  Wind onshore    733.3
# 28      EG       Battery    885.7
# 29      EG           CHP     16.1
# 30      EG  Gas turbines      0.7
# 31      EG         Hydro      7.7
# 32      EG       Nuclear     38.6
# 33      EG      Solar PV  12751.5
# 34      EG  Wind onshore   6002.3

# %%
fig_name = "electricity_supply_TWh"
fig = px.bar(
    supply_df, 
    **fig_kwargs,
    labels={"value":"Electricity supply in TWh<sub>el</sub>",
            "year":"",
            "variable":"", 
            "scen":""
            },
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    #facet_col_wrap=1, facet_col_spacing=0.07,
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)

fig.show()

#save_plotly_fig(supply_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                                               value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG        1498.1
#                                   H2m1.0+H2v1.0+3H            2050 EG        1586.6
#                                   H2m1.0+NH3v1.0+3H           2050 EG        1604.4
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG        1623.1
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       19702.6
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="6f82a4d7-a084-478c-9aa1-4eb2fc48da99" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6f82a4d7-a084-478c-9aa1-4eb2fc48da99")) {                    Plotly.newPlot(                        "6f82a4d7-a084-478c-9aa1-4eb2fc48da99",                        [{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmdhUAAAAAAAJyHQDMzMzMz24dAAAAAAAA4iEAAAAAAwOfIQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmdhUAAAAAAAJyHQDMzMzMz24dAAAAAAAA4iEAAAAAAwOfIQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzObhUAzMzMzM1uGQGZmZmZmroZAZmZmZmbqhkDNzMzMTHK3QA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzObhUAzMzMzM1uGQGZmZmZmroZAZmZmZmbqhkDNzMzMTHK3QA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMHkDNzMzMzMweQM3MzMzMzB5AzczMzMzMHkDNzMzMzMweQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMHkDNzMzMzMweQM3MzMzMzB5AzczMzMzMHkDNzMzMzMweQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nuclear","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Nuclear","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzQUDNzMzMzExBQM3MzMzMTEFAzczMzMxMQUDNzMzMzExDQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzQUDNzMzMzExBQM3MzMzMTEFAzczMzMxMQUDNzMzMzExDQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZBUCamZmZmZkFQJqZmZmZmQVAZmZmZmZmBkBmZmZmZmbmPw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+ ...

# %%
fig_name = "electricity_demand_TWh"
fig = px.bar(
    demand_df, 
    **fig_kwargs,
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    labels={"value":"Electricity demand in TWh<sub>el</sub>","year":"",
            "variable":"", 
            "scen":""},
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(demand_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                                               value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG        1498.2
#                                   H2m1.0+H2v1.0+3H            2050 EG        1586.6
#                                   H2m1.0+NH3v1.0+3H           2050 EG        1604.6
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG        1623.2
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       19702.6
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="4b780136-7419-4878-94c5-17d1fc3adbc4" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4b780136-7419-4878-94c5-17d1fc3adbc4")) {                    Plotly.newPlot(                        "4b780136-7419-4878-94c5-17d1fc3adbc4",                        [{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#f58220","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMxMXUDNzMzMzExdQM3MzMzMTF1AzczMzMxMXUDNzMzMzExdQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMxMXUDNzMzMzExdQM3MzMzMTF1AzczMzMxMXUDNzMzMzExdQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commerce","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Commerce","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACAXEAAAAAAAIBcQAAAAAAAgFxAAAAAAACAXEAAAAAAAIBcQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAACAXEAAAAAAAIBcQAAAAAAAgFxAAAAAAACAXEAAAAAAAIBcQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ammonia synthesis","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Ammonia synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM9D\u002fNzMzMzMz0Pw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM9D\u002fNzMzMzMz0Pw=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","marker":{"color":"#f08591","pattern":{"shape":""}},"name":"Agriculture","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzK0AzMzMzMzMrQDMzMzMzMytAMzMzMzMzK0AzMzMzMzMrQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzK0AzMzMzMzMrQDMzMzMzMytAMzMzMzMzK0AzMzMzMzMrQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rail transport","marker":{"color":"#008598","pattern":{"shape":""}},"name":"Rail transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz+z8zMzMzMzP7PzMzMzMzM\u002fs\u002fMzMzMzMz+z8zMzMzMzP7Pw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz+z8zMzMzMzP7PzMzMzMzM\u002fs\u00 ...

# %% [markdown]
# ## Energy and feedstock market balance | Hydrogen

# %%
df = prepare_dataframe(balance_dict["H2"], idx_group, set_scen_col)
df = df[df["value"]!=0]
df.variable = df.variable.map(rename_h2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
df
# Out:
#    run_name_prefix           run_name                         scen  year  \
# 0              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 1              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 3              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 4              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 6              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 7              DKS  DKS_EG_2050_eopts             H2m1.0+H2v0.5+3H  2050
# 9              DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 10             DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 12             DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 13             DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 15             DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 16             DKS  DKS_EG_2050_eopts             H2m1.0+H2v1.0+3H  2050
# 18             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 19             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 21             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 22             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 23             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 24             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 25             DKS  DKS_EG_2050_eopts            H2m1.0+NH3v1.0+3H  2050
# 27             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 28             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 30             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 31             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 32             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 33             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 34             DKS  DKS_EG_2050_eopts     H2m1.0+NH3v1.0+FTv1.0+3H  2050
# 36             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 37             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 39             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 40             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 42             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
# 43             DKS  DKS_EG_2050_eopts  H2v1.01+NH3v1.01+FTv1.01+3H  2050
#
#    country           variable    value
# 0       EG    Power-to-liquid   -228.0
# 1       EG    H2 Electrolysis    601.8
# 3       EG          H2 export    -62.5
# 4       EG           Shipping     -2.9
# 6       EG       Power-to-gas   -303.0
# 7       EG     Land transport     -5.3
# 9       EG    Power-to-liquid   -228.0
# 10      EG    H2 Electrolysis    664.1
# 12      EG          H2 export   -125.0
# 13      EG           Shipping     -2.9
# 15      EG       Power-to-gas   -302.9
# 16      EG     Land transport     -5.3
# 18      EG    Power-to-liquid   -228.0
# 19      EG    H2 Electrolysis    676.3
# 21      EG          H2 export   -125.0
# 22      EG           Shipping     -2.9
# 23      EG  Ammonia synthesis    -12.1
# 24      EG       Power-to-gas   -303.0
# 25      EG     Land transport     -5.3
# 27      EG    Power-to-liquid   -241.1
# 28      EG    H2 Electrolysis    689.5
# 30      EG          H2 export   -125.0
# 31      EG           Shipping     -2.9
# 32      EG  Ammonia synthesis    -12.1
# 33      EG       Power-to-gas   -303.1
# 34      EG     Land transport     -5.3
# 36      EG    Power-to-liquid -12081.6
# 37      EG    H2 Electrolysis  12178.1
# 39      EG          H2 export    -18.0
# 40      EG           Shipping     -2.9
# 42      EG       Power-to-gas    -70.3
# 43      EG     Land transport     -5.3

# %%
supply_sum_df
# Out:
#                                                                               value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG         601.8
#                                   H2m1.0+H2v1.0+3H            2050 EG         664.1
#                                   H2m1.0+NH3v1.0+3H           2050 EG         676.3
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG         689.5
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       12178.1

# %%
demand_sum_df
# Out:
#                                                                               value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG         601.7
#                                   H2m1.0+H2v1.0+3H            2050 EG         664.1
#                                   H2m1.0+NH3v1.0+3H           2050 EG         676.3
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG         689.5
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       12178.1

# %%
fig_name = "hydrogen_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["hydrogen"],
    category_orders={
        "variable":list(colors["hydrogen"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"H2 balance in TWh","year":"",
            "variable":"", 
            "scen": ""},

)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                                               value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG         601.7
#                                   H2m1.0+H2v1.0+3H            2050 EG         664.1
#                                   H2m1.0+NH3v1.0+3H           2050 EG         676.3
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG         689.5
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       12178.1
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="ee193c57-5c8d-4345-af6d-10142a2fd946" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ee193c57-5c8d-4345-af6d-10142a2fd946")) {                    Plotly.newPlot(                        "ee193c57-5c8d-4345-af6d-10142a2fd946",                        [{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmbOgkDNzMzMzMCEQGZmZmZmIoVAAAAAAACMhUDNzMzMDMnHQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmbOgkDNzMzMzMCEQGZmZmZmIoVAAAAAAACMhUDNzMzMDMnHQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Land transport","marker":{"color":"#669db2","pattern":{"shape":""}},"name":"Land transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzFcAzMzMzMzMVwDMzMzMzMxXAMzMzMzMzFcAzMzMzMzMVwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzFcAzMzMzMzMVwDMzMzMzMxXAMzMzMzMzFcAzMzMzMzMVwA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ammonia synthesis","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Ammonia synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzKMAzMzMzMzMowA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzKMAzMzMzMzMowA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-gas","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Power-to-gas","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAADwcsBmZmZmZu5ywAAAAAAA8HLAmpmZmZnxcsAzMzMzM5NRwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAADwcsBmZmZmZu5ywAAAAAAA8HLAmpmZmZnxcsAzMzMzM5NRwA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-liquid","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Power-to-liquid","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACAbMAAAAAAAIBswAAAAAAAgGzAMzMzMzMjbsDNzMzMzJjHwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAACAbMAAAAAAAIBswAAAAAAAgGzAMzMzMzMjbsDNzMzMzJjHwA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 ...

# %% [markdown]
# ## Energy and feedstock market balance | Liquid fuel

# %%
df = prepare_dataframe(balance_dict["oil"], idx_group, set_scen_col)
df = df[df["value"]!=0]
df.variable = df.variable.map(rename_oil)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "liquid_fuel_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["oil"],
    category_orders={
        "variable":list(colors["oil"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"Liquid fuel balance in TWh","year":"",
            "variable":"", 
            "scen":""},

)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                                              value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG        174.1
#                                   H2m1.0+H2v1.0+3H            2050 EG        174.1
#                                   H2m1.0+NH3v1.0+3H           2050 EG        174.1
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG        184.1
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       9218.4
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="0e9fc2da-a241-45fc-87bc-48a63d6a70ba" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0e9fc2da-a241-45fc-87bc-48a63d6a70ba")) {                    Plotly.newPlot(                        "0e9fc2da-a241-45fc-87bc-48a63d6a70ba",                        [{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-liquid","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Power-to-liquid","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAADAZUAAAAAAAMBlQAAAAAAAwGVAAAAAAAAAZ0CamZmZGQHCQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAADAZUAAAAAAAMBlQAAAAAAAwGVAAAAAAAAAZ0CamZmZGQHCQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Land transport","marker":{"color":"#669db2","pattern":{"shape":""}},"name":"Land transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMLcDNzMzMzMwtwM3MzMzMzC3AzczMzMzMLcDNzMzMzMwtwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMLcDNzMzMzMwtwM3MzMzMzC3AzczMzMzMLcDNzMzMzMwtwA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maritime","marker":{"color":"#39c1cd","pattern":{"shape":""}},"name":"Maritime","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMGsDNzMzMzMwawM3MzMzMzBrAzczMzMzMGsDNzMzMzMwawA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMGsDNzMzMzMwawM3MzMzMzBrAzczMzMzMGsDNzMzMzMwawA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aviation","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Aviation","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZkZQcCamZmZmRlBwJqZmZmZGUHAmpmZmZkZQcCamZmZmRlBwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZkZQcCamZmZmRlBwJqZmZmZGUHAmpmZmZkZQcCamZmZmRlBwA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#f58220","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzPTVsAzMzMzM9NWwDMzMzMz01bAMzMzMzPTVsAzMzMzM9NWwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzPTVsAzMzMzM9NWwDMzMzMz01bAMzMzMzPTVsAzMzMzM9NWwA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\ ...

# %% [markdown]
# ## Energy and feedstock market balance | CH4

# %%
df = prepare_dataframe(balance_dict["gas"], idx_group, set_scen_col)
df = df[df["value"]!=0]
df.variable = df.variable.map(rename_gas)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "CH4_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["gas"],
    category_orders={
        "variable":list(colors["gas"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"CH4 balance in TWh","year":"",
            "variable":"", 
            "scen":""},

)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                                             value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG       240.6
#                                   H2m1.0+H2v1.0+3H            2050 EG       240.5
#                                   H2m1.0+NH3v1.0+3H           2050 EG       240.6
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG       240.6
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       232.8
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="022a2efd-ff28-4573-a6f4-061af10d5c9f" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("022a2efd-ff28-4573-a6f4-061af10d5c9f")) {                    Plotly.newPlot(                        "022a2efd-ff28-4573-a6f4-061af10d5c9f",                        [{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-gas","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Power-to-gas","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzPjbUAAAAAAAOBtQDMzMzMz421AZmZmZmbmbUAAAAAAAMBLQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzPjbUAAAAAAAOBtQDMzMzMz421AZmZmZmbmbUAAAAAAAMBLQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas import","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Gas import","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAZkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAZkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmEsAAAAAAAAASwGZmZmZmZhLAzczMzMzMEsCamZmZmZnxvw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmEsAAAAAAAAASwGZmZmZmZhLAzczMzMzMEsCamZmZmZnxvw=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Residential","marker":{"color":"#f58220","pattern":{"shape":""}},"name":"Residential","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmPcBmZmZmZmY9wGZmZmZmZj3AZmZmZmZmPcBmZmZmZmY9wA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmPcBmZmZmZmY9wGZmZmZmZj3AZmZmZmZmPcBmZmZmZmY9wA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzQcA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzQcA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biogas","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Biogas","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZm9j9mZmZmZmb2P2ZmZmZmZvY\u002fZmZmZmZm9j9mZmZmZmb2Pw=="},"textposition":"inside","texttemplate":"%{y: ...

# %% [markdown]
# ## Energy and feedstock market balance | CO2

# %%
df = prepare_dataframe(balance_dict["co2 stored"], idx_group, set_scen_col)
df = df[df["value"]!=0]

df.variable = df.variable.map(rename_co2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["co2"],
    category_orders={
        "variable":list(colors["gas"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"CO<sub>2</sub> Capture (+) and Usage (-) in Mt","year":"","variable":"", "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_CO2_capture_and_usage_Mt")
# Out:
# Totals per scenario and year:                                                                              value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG        157.2
#                                   H2m1.0+H2v1.0+3H            2050 EG        157.2
#                                   H2m1.0+NH3v1.0+3H           2050 EG        157.2
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG        159.9
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       2481.4
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="6008d4fc-8076-4a39-98a7-8318be058554" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6008d4fc-8076-4a39-98a7-8318be058554")) {                    Plotly.newPlot(                        "6008d4fc-8076-4a39-98a7-8318be058554",                        [{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-gas","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Power-to-gas","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmamR8BmZmZmZqZHwGZmZmZmpkfAMzMzMzOzR8AAAAAAAAAmwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmamR8BmZmZmZqZHwGZmZmZmpkfAMzMzMzOzR8AAAAAAAAAmwA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Direct air capture","marker":{"color":"#7c154d","pattern":{"shape":""}},"name":"Direct air capture","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMGkDNzMzMzMwaQM3MzMzMzBpAmpmZmZmZIUBmZmZmZiiiQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMGkDNzMzMzMwaQM3MzMzMzBpAmpmZmZmZIUBmZmZmZiiiQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-liquid","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Power-to-liquid","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZlZRsCamZmZmVlGwJqZmZmZWUbAZmZmZmamR8DNzMzMzISiwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZlZRsCamZmZmVlGwJqZmZmZWUbAZmZmZmamR8DNzMzMzISiwA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"co2 stored","marker":{"color":"#8C564B","pattern":{"shape":""}},"name":"co2 stored","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMxMUMDNzMzMzExQwM3MzMzMTFDAzczMzMxMUMAAAAAAAABZwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMxMUMDNzMzMzExQwM3MzMzMTFDAzczMzMxMUMAAAAAAAABZwA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas for industry with CC","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Gas for industry with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmQ0BmZmZmZmZDQGZmZmZmZkNAZmZmZmZmQ0CamZmZmZk\u002fQA=="},"textposition":"inside","texttemplate":"%{y:.0f}"," ...

# %% [markdown]
# ## CO2 atmosphere balance

# %%
df = prepare_dataframe(balance_dict["co2"], idx_group, set_scen_col)

df.variable = df.variable.map(rename_co2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "co2_emissions_mt"
fig = px.bar(
    df, 
    **fig_kwargs,
    labels={"value":"CO2 emissions in Mt<sub>CO2</sub>",
            "year":"",
            "variable":"", 
            "scen":""
            },
    color_discrete_map=colors["co2"],
    category_orders={
        "variable":list(colors["co2"].keys()),
        "scen": scen_order
        },
    #facet_col_wrap=1, facet_col_spacing=0.07,
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(supply_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                                              value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG         83.0
#                                   H2m1.0+H2v1.0+3H            2050 EG         83.0
#                                   H2m1.0+NH3v1.0+3H           2050 EG         83.0
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG         85.6
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       2414.3
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="f4946617-7702-4d5d-b8ab-f7f637f7fd2e" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f4946617-7702-4d5d-b8ab-f7f637f7fd2e")) {                    Plotly.newPlot(                        "f4946617-7702-4d5d-b8ab-f7f637f7fd2e",                        [{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Process emissions with CC","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Process emissions with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmFEBmZmZmZmYUQGZmZmZmZhRAZmZmZmZmFEBmZmZmZmYUQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmFEBmZmZmZmYUQGZmZmZmZhRAZmZmZmZmFEBmZmZmZmYUQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biomass for industry with CC","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Biomass for industry with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZE8CamZmZmZkTwJqZmZmZmRPAmpmZmZmZE8CamZmZmZkTwA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZE8CamZmZmZkTwJqZmZmZmRPAmpmZmZmZE8CamZmZmZkTwA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biomass for CHP with CC","marker":{"color":"#C2D05C","pattern":{"shape":""}},"name":"Biomass for CHP with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAJcAAAAAAAAAlwAAAAAAAACXAAAAAAAAAJsDNzMzMzEw4wA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAJcAAAAAAAAAlwAAAAAAAACXAAAAAAAAAJsDNzMzMzEw4wA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas for industry with CC","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Gas for industry with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAAEAAAAAAAAAAQAAAAAAAAABAAAAAAAAAAEAzMzMzMzP7Pw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAEAAAAAAAAAAQAAAAAAAAABAAAAAAAAAAEAzMzMzMzP7Pw=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Direct air capture","marker":{"color":"#7c154d","pattern":{"shape":""}},"name":"Direct air capture","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMGsDNzMzMzMwawM3MzMzMzBrAmpmZmZmZIcBmZmZmZiiiwA=="},"textposition":"inside","texttemplate":"%{y ...

# %%
df = prepare_dataframe(optimal_capacity_dict["AC"], idx_group, set_scen_col)
df = df[df["value"]<1e6] #drop loadshedding capacity
df.variable = df.variable.map(rename_electricity).map(rename_to_upper_case)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "electricity_installed_capacity_GW"
fig = px.bar(
    df, 
    **fig_kwargs,
    #barmode="stack",
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    #range_y=(0,supply_sum_df.max().value*1.1),
    labels={"value":"Installed capacity in GW<sub>el</sub>","year":"",
            #"variable":"",
            "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                                               value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG       27768.2
#                                   H2m1.0+H2v1.0+3H            2050 EG       27820.0
#                                   H2m1.0+NH3v1.0+3H           2050 EG       27827.4
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG       27836.9
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       38677.6
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="fc0cf72a-dac6-4091-b7d7-f2d761f4787b" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fc0cf72a-dac6-4091-b7d7-f2d761f4787b")) {                    Plotly.newPlot(                        "fc0cf72a-dac6-4091-b7d7-f2d761f4787b",                        [{"hovertemplate":"variable=Solar PV\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZlhe0AAAAAAAAB+QM3MzMzMRH5AZmZmZma+fkAAAAAAAArAQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZlhe0AAAAAAAAB+QM3MzMzMRH5AZmZmZma+fkAAAAAAAArAQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Wind onshore\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMxMakAzMzMzMzNrQAAAAAAAoGtAZmZmZmbma0AzMzMzMzWgQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMxMakAzMzMzMzNrQAAAAAAAoGtAZmZmZmbma0AzMzMzMzWgQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Hydro\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzA0BmZmZmZmYGQDMzMzMzMwNAZmZmZmZmBkAzMzMzMzMDQGZmZmZmZgZAMzMzMzMzA0BmZmZmZmYGQDMzMzMzMwNAZmZmZmZmBkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzA0BmZmZmZmYGQDMzMzMzMwNAZmZmZmZmBkAzMzMzMzMDQGZmZmZmZgZAMzMzMzMzA0BmZmZmZmYGQDMzMzMzMwNAZmZmZmZmBkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Nuclear\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nuclear","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Nuclear","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzE0AzMzMzMzMTQDMzMzMzMxNAMzMzMzMzE0AzMzMzMzMTQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzE0AzMzMzMzMTQDMzMzMzMxNAMzMzMzMzE0AzMzMzMzMTQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Gas turbines\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas tu ...

# %%
df = prepare_dataframe(optimal_capacity_dict["H2"], idx_group, set_scen_col)
df = df[df["value"]<1e6] #drop loadshedding capacity
df.variable = df.variable.map(rename_h2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "hydrogen_installed_capacity_GW"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map={"H2 Electrolysis":"#179c7d"},
    category_orders={
        #"variable":list(colors["gas"].keys())
        "scen": scen_order
        },
    labels={"value":"Installed capacity in GW<sub>H2</sub>","year":"","variable":"","scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                                               value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG       27117.5
#                                   H2m1.0+H2v1.0+3H            2050 EG       27133.9
#                                   H2m1.0+NH3v1.0+3H           2050 EG       27136.0
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG       27139.1
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       29963.3
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="413045f8-fbd2-4687-b918-265f498f9a7e" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("413045f8-fbd2-4687-b918-265f498f9a7e")) {                    Plotly.newPlot(                        "413045f8-fbd2-4687-b918-265f498f9a7e",                        [{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAABgXUDNzMzMzLxgQAAAAAAAAGFAMzMzMzNjYUCamZmZmSanQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAABgXUDNzMzMzLxgQAAAAAAAAGFAMzMzMzNjYUCamZmZmSanQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"load shedding","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"load shedding","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAABe2kAAAAAAAF7aQAAAAAAAXtpAAAAAAABe2kAAAAAAAF7aQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAABe2kAAAAAAAF7aQAAAAAAAXtpAAAAAAABe2kAAAAAAAF7aQA=="},"yaxis":"y","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.555555555555555 ...

# %%
stats_df = pd.concat([costs_dict["capex"],costs_dict["opex"]],axis=0)
df = prepare_dataframe(stats_df, idx_group, set_scen_col)
df.variable = df.variable.map(rename_costs) # ToDo rename important cost components
df = df.groupby(["run_name_prefix", "scen", "year", "country", "variable"], as_index=False).sum().round(1)
df = df[df["value"]!=0]

# (supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df, threshold=0., round=1)

# %%
fig_name = "system_costs_billion_eur" # expenditure and export revenue
fig_kwargs["height"] = heights["3"]
fig_kwargs["text_auto"] = ".1f"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["costs"],
    category_orders={
        "variable":list(colors["costs"].keys()),
        #"scen": scen_order
        },
    facet_col_spacing=0.1,
    labels={"value":"System costs in billion EUR20XX/year","year":"", 
            #"variable":"", 
            "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_installed_capacity_AC_GW")
# Out:
# Totals per scenario and year:                                                                               value
# run_name_prefix run_name          scen                        year country
# DKS             DKS_EG_2050_eopts H2m1.0+H2v0.5+3H            2050 EG       27117.5
#                                   H2m1.0+H2v1.0+3H            2050 EG       27133.9
#                                   H2m1.0+NH3v1.0+3H           2050 EG       27136.0
#                                   H2m1.0+NH3v1.0+FTv1.0+3H    2050 EG       27139.1
#                                   H2v1.01+NH3v1.01+FTv1.01+3H 2050 EG       29963.3
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="52bd70fa-45fa-44ea-8bf2-d968fde4883e" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("52bd70fa-45fa-44ea-8bf2-d968fde4883e")) {                    Plotly.newPlot(                        "52bd70fa-45fa-44ea-8bf2-d968fde4883e",                        [{"hovertemplate":"variable=Solar\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZkZMEAzMzMzM7MxQM3MzMzMzDFAmpmZmZkZMkBmZmZmZuZyQA=="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x4","y":{"dtype":"f8","bdata":"mpmZmZkZMEAzMzMzM7MxQM3MzMzMzDFAmpmZmZkZMkBmZmZmZuZyQA=="},"yaxis":"y4","type":"bar","textangle":0},{"hovertemplate":"variable=Wind\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzOzQEAAAAAAAEBBQAAAAAAAgEFAMzMzMzOzQUAAAAAAAJB0QA=="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x4","y":{"dtype":"f8","bdata":"MzMzMzOzQEAAAAAAAEBBQAAAAAAAgEFAMzMzMzOzQUAAAAAAAJB0QA=="},"yaxis":"y4","type":"bar","textangle":0},{"hovertemplate":"variable=H2 Electrolysis\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMLEBmZmZmZmYwQJqZmZmZmTBAAAAAAAAAMUDNzMzMzJx2QA=="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x4","y":{"dtype":"f8","bdata":"zczMzMzMLEBmZmZmZmYwQJqZmZmZmTBAAAAAAAAAMUDNzMzMzJx2QA=="},"yaxis":"y4","type":"bar","textangle":0},{"hovertemplate":"variable=H2 export\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 export","marker":{"color":"#7c154d","pattern":{"shape":""}},"name":"H2 export","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM\u002fL8="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x4","y":{"dtype":"f8","bdata":"zczMzMzM\u002fL8="},"yaxis":"y4","type":"bar","textangle":0},{"hovertemplate":"variable=Transmission line\u003cbr\u003erun_name=DKS_EG_2050_eopts\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Transmission line","marker":{"color":"#4cc2a6","pattern":{"shape":""}},"name":"Transmission line","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzFUAzMzMzMzMVQDMzMzMzMxVAMzMzMzMzFUBmZmZmZmYcQA=="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["H2m1.0+H2v0.5+3H","H2m1.0+H2v1.0+3H","H2m1.0+NH3v1.0+3H","H2m1.0+NH3v1.0+FTv1.0+3H","H2v1.01+NH3v1.01+FTv1.01+3H"],"xaxis":"x4","y":{"dtype":"f8","bdata":"MzMzMzMzFUAzMzMzMzMVQDMzMzMzMxVAMzMzMzMzFUB ...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Relative costs
#
# costs / total energy consumption

# %% [markdown]
# ## Water consumption
