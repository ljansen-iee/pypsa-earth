# %% [markdown]
# # Plot Summary
#
# Create publication-ready visualizations of PyPSA optimization results including energy balances, installed capacities, and system costs.
#
# **How to use:**
# 1. Run `make_stats_dict.py` to extract statistics from network files
# 2. Update `plot_summary.yaml` with your experiment configuration (countries, years, scenarios)
# 3. Execute cells below to generate all plots automatically
#
# **Configuration:** Edit `plot_summary.yaml` to switch between experiments, filter scenarios, or adjust plot styling without changing code.
#
# **Environment:** Install `envs/pypsa-earth-vis.yaml`

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import pandas as pd
idx_slice = pd.IndexSlice
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)
import plotly.express as px

# import sys
# sys.path.append('../scripts')
from plot_helpers import (
    chdir_to_root_dir,
    read_stats_dict,
    prepare_dataframe,
    rename_electricity, 
    rename_h2,
    rename_gas,
    rename_oil,
    rename_co2,
    rename_costs,
    colors,
    save_plotly_fig,
    get_scen_col_function,
    apply_standard_styling,
    plot_energy_balance,
    plot_capacity,
    load_plot_config
)

chdir_to_root_dir()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load configuration from YAML file
yaml_config = load_plot_config()

# Extract configuration
RUN_NAME_PREFIX = yaml_config['run']['name_prefix']
SUMMARY_VERSION = yaml_config['run']['summary_version']
SDIR = Path.cwd() / "results" / f"{RUN_NAME_PREFIX}_summary_{SUMMARY_VERSION}"
SDIR.mkdir(exist_ok=True, parents=True)

COUNTRIES = yaml_config['data']['countries']
YEARS = yaml_config['data']['years']
INDEX_LEVELS_TO_DROP = yaml_config['data']['index_levels_to_drop']

# Build index group
IDX_GROUP = idx_slice[[RUN_NAME_PREFIX], :, COUNTRIES, YEARS]
IDX_GROUP_NAME = "".join(COUNTRIES) + "_MAIN"

print(f"Index Group Name: {IDX_GROUP_NAME}")
print(f"Index Group: {IDX_GROUP}")

# Scenario filtering
SCEN_FILTER = yaml_config['data']['scen_filter']
scen_order = yaml_config['data']['scen_order']

# Get scenario column function
scen_col_func_name = yaml_config['data']['scen_col_function']
set_scen_col = get_scen_col_function(scen_col_func_name)
print(f"Using scenario column function: {scen_col_func_name}")

# Plot dimensions
width = yaml_config['plot']['width']
heights = yaml_config['plot']['heights']

# Default figure kwargs
fig_kwargs = yaml_config['plot']['default_kwargs'].copy()
fig_kwargs['width'] = width
fig_kwargs['height'] = heights['medium']

print(f"\nConfiguration loaded successfully!")
print(f"Countries: {COUNTRIES}")
print(f"Years: {YEARS}")
print(f"Scenario filter: {SCEN_FILTER if SCEN_FILTER else 'None (show all)'}")
# Out:
# Index Group Name: MA_MAIN
# Index Group: (['MAPaper'], slice(None, None, None), ['MA'], [2035])
# Using scenario column function: MAPaper
#
# Configuration loaded successfully!
# Countries: ['MA']
# Years: [2035]
# Scenario filter: None (show all)

# %%
# Load data dictionaries using configuration
balance_keys = yaml_config['carriers']['balance']
capacity_keys = yaml_config['carriers']['capacity']
cost_keys = yaml_config['carriers']['costs']

balance_dict = read_stats_dict("balance_dict", SDIR, keys=balance_keys)
optimal_capacity_dict = read_stats_dict("optimal_capacity_dict", SDIR, keys=capacity_keys)
costs_dict = read_stats_dict("costs_dict", SDIR, keys=cost_keys)

print(f"Loaded balance data for: {balance_keys}")
print(f"Loaded capacity data for: {capacity_keys}")
print(f"Loaded cost data for: {cost_keys}")
# Out:
# Imported AC from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/balance_dict_AC.csv
# Imported H2 from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/balance_dict_H2.csv
# Imported oil from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/balance_dict_oil.csv
# Imported gas from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/balance_dict_gas.csv
# Imported co2 stored from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/balance_dict_co2 stored.csv
# Imported co2 from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/balance_dict_co2.csv
# Imported NH3 from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/balance_dict_NH3.csv
# Imported HBI from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/balance_dict_HBI.csv
# Imported AC from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/optimal_capacity_dict_AC.csv
# Imported H2 from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/optimal_capacity_dict_H2.csv
# Imported HBI from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/optimal_capacity_dict_HBI.csv
# Imported capex from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/costs_dict_capex.csv
# Imported opex from /mnt/data/gsa/pypsa-earth-custom-lukas/results/MAPaper_summary_v6/costs_dict_opex.csv
# Loaded balance data for: ['AC', 'H2', 'oil', 'gas', 'co2 stored', 'co2', 'NH3', 'HBI']
# Loaded capacity data for: ['AC', 'H2', 'HBI']
# Loaded cost data for: ['capex', 'opex']

# %% [markdown]
# ## Plots

# %%
plot_config = {
    'idx_group': IDX_GROUP,
    'idx_group_name': IDX_GROUP_NAME,
    'index_levels_to_drop': INDEX_LEVELS_TO_DROP,
    'set_scen_col_func': set_scen_col,
    'scen_filter': SCEN_FILTER,
    'scen_order': scen_order,
    'fig_kwargs': fig_kwargs,
    'heights': heights,
}

# %% [markdown]
# ### Electricity Supply

# %%
plot_config['chart_config'] = yaml_config['charts']['electricity_supply']

fig, df = plot_energy_balance(
    carrier="AC",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_electricity,
    show_supply=True,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="3291bf35-ae72-486e-9f05-8d711595f3de" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3291bf35-ae72-486e-9f05-8d711595f3de")) {                    Plotly.newPlot(                        "3291bf35-ae72-486e-9f05-8d711595f3de",                        [{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzOzNkAzMzMzMzM\u002fQGZmZmZmZjdAAAAAAABAQEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzOzNkAzMzMzMzM\u002fQGZmZmZmZjdAAAAAAABAQEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMyMRkAzMzMzM\u002fNUQM3MzMzMjERAMzMzMzOzVUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMyMRkAzMzMzM\u002fNUQM3MzMzMjERAMzMzMzOzVUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coal","marker":{"color":"#454545","pattern":{"shape":""}},"name":"Coal","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMQUBmZmZmZmYgQDMzMzMzM0JAZmZmZmZmEkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMQUBmZmZmZmYgQDMzMzMzM0JAZmZmZmZmEkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM9D\u002fNzMzMzMz0P83MzMzMzPQ\u002fzczMzMzM9D8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM9D\u002fNzMzMzMz0P83MzMzMzPQ\u002fzczMzMzM9D8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAQECamZmZmZkoQDMzMzMzM0dAAAAAAACAN0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAQECamZmZmZkoQDMzMzMzM0dAAAAAAACAN0A="},"yaxis":"y","type":"bar","textangle":0},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["137","137","149","149"],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"top center","x":["Exp-H2v1.0 ...

# %% [markdown]
# ### Electricity Demand

# %%
plot_config['chart_config'] = yaml_config['charts']['electricity_demand']

fig, df = plot_energy_balance(
    carrier="AC",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_electricity,
    show_supply=False,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="2095cb89-14ef-4b61-abd4-8bf109634d33" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2095cb89-14ef-4b61-abd4-8bf109634d33")) {                    Plotly.newPlot(                        "2095cb89-14ef-4b61-abd4-8bf109634d33",                        [{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAEkAAAAAAAAASQM3MzMzMzCFAzczMzMzMIUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAEkAAAAAAAAASQM3MzMzMzCFAzczMzMzMIUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commerce","marker":{"color":"#008598","pattern":{"shape":""}},"name":"Commerce","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAIUAAAAAAAAAhQAAAAAAAACFAAAAAAAAAIUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAIUAAAAAAAAAhQAAAAAAAACFAAAAAAAAAIUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Residential","marker":{"color":"#39c1cd","pattern":{"shape":""}},"name":"Residential","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACAQUAAAAAAAIBBQAAAAAAAgEFAAAAAAACAQUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAACAQUAAAAAAAIBBQAAAAAAAgEFAAAAAAACAQUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Transport","marker":{"color":"#a8508c","pattern":{"shape":""}},"name":"Transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzHUAzMzMzMzMdQDMzMzMzMx1AMzMzMzMzHUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzHUAzMzMzMzMdQDMzMzMzMx1AMzMzMzMzHUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmSEBmZmZmZmZIQAAAAAAAAExAAAAAAAAATEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmSEBmZmZmZmZIQAAAAAAAAExAAAAAAAAATEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity consumption [TWh\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"agriculture ...

# %% [markdown]
# ### Electricity Installed Capacity

# %%
optimal_capacity_dict["AC"]
# Out:
#                                                                                                                     CCGT  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0   5.6
#                                                                                           Exp    H2v1.0              4.5
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0   3.8
#                                                                                           Exp    H2v1.0              1.8
#
#                                                                                                                     H2 Fuel Cell  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0           0.0
#                                                                                           Exp    H2v1.0                      0.0
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0           0.0
#                                                                                           Exp    H2v1.0                      0.0
#
#                                                                                                                     H2 turbine  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0         0.0
#                                                                                           Exp    H2v1.0                    0.0
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0         0.0
#                                                                                           Exp    H2v1.0                    0.0
#
#                                                                                                                     OCGT  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0   2.2
#                                                                                           Exp    H2v1.0              0.6
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0   0.0
#                                                                                           Exp    H2v1.0              0.0
#
#                                                                                                                     PHS  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0  0.8
#                                                                                           Exp    H2v1.0             0.8
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0  0.8
#                                                                                           Exp    H2v1.0             0.8
#
#                                                                                                                     battery discharger  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0                 0.0
#                                                                                           Exp    H2v1.0                            0.0
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0                 0.0
#                                                                                           Exp    H2v1.0                            0.0
#
#                                                                                                                     biomass EOP  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0          0.0
#                                                                                           Exp    H2v1.0                     0.0
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0          0.0
#                                                                                           Exp    H2v1.0                     0.0
#
#                                                                                                                     coal  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0   4.3
#                                                                                           Exp    H2v1.0              4.3
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0   4.3
#                                                                                           Exp    H2v1.0              4.3
#
#                                                                                                                     hydro  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0    1.3
#                                                                                           Exp    H2v1.0               1.3
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0    1.3
#                                                                                           Exp    H2v1.0               1.3
#
#                                                                                                                     load shedding  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0            7.6
#                                                                                           Exp    H2v1.0                       7.6
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0            7.6
#                                                                                           Exp    H2v1.0                       7.6
#
#                                                                                                                     oil  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0  1.7
#                                                                                           Exp    H2v1.0             1.7
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0  1.7
#                                                                                           Exp    H2v1.0             1.7
#
#                                                                                                                     onwind  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0    10.6
#                                                                                           Exp    H2v1.0               11.6
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0    25.1
#                                                                                           Exp    H2v1.0               23.7
#
#                                                                                                                     ror  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0  0.5
#                                                                                           Exp    H2v1.0             0.5
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0  0.5
#                                                                                           Exp    H2v1.0             0.5
#
#                                                                                                                     solar  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0   15.6
#                                                                                           Exp    H2v1.0              15.2
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0   21.8
#                                                                                           Exp    H2v1.0              20.9
#
#                                                                                                                     urban central gas CHP  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0                    0.0
#                                                                                           Exp    H2v1.0                               0.0
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0                    0.0
#                                                                                           Exp    H2v1.0                               0.0
#
#                                                                                                                     urban central gas CHP CC  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0                       0.0
#                                                                                           Exp    H2v1.0                                  0.0
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0                       0.0
#                                                                                           Exp    H2v1.0                                  0.0
#
#                                                                                                                     urban central solid biomass CHP  \
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0                              0.0
#                                                                                           Exp    H2v1.0                                         0.0
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0                              0.0
#                                                                                           Exp    H2v1.0                                         0.0
#
#                                                                                                                     urban central solid biomass CHP CC
# run_name_prefix run_name     country year simpl clusters ll   opts     sopts discountrate demand eopts
# MAPaper         MAPaper_2035 MA      2035 NaN   10       v1.1 NaN      1H    0.078        IR     HBIv1.0+STEELv1.0                                 0.0
#                                                                                           Exp    H2v1.0                                            0.0
#                                                               Co2L1.09 1H    0.078        IR     HBIv1.0+STEELv1.0                                 0.0
#                                                                                           Exp    H2v1.0                                            0.0

# %%
plot_config['chart_config'] = yaml_config['charts']['electricity_capacity']

fig, df = plot_capacity(
    carrier="AC",
    capacity_dict=optimal_capacity_dict,
    config=plot_config,
    rename_function=rename_electricity,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="7a336726-d507-4816-adf9-5dfea8d16f8e" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7a336726-d507-4816-adf9-5dfea8d16f8e")) {                    Plotly.newPlot(                        "7a336726-d507-4816-adf9-5dfea8d16f8e",                        [{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmLkBmZmZmZuY0QDMzMzMzMy9AzczMzMzMNUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmLkBmZmZmZuY0QDMzMzMzMy9AzczMzMzMNUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzJ0AzMzMzM7M3QDMzMzMzMyVAmpmZmZkZOUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzJ0AzMzMzM7M3QDMzMzMzMyVAmpmZmZkZOUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coal","marker":{"color":"#454545","pattern":{"shape":""}},"name":"Coal","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzEUAzMzMzMzMRQDMzMzMzMxFAMzMzMzMzEUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzEUAzMzMzMzMRQDMzMzMzMxFAMzMzMzMzEUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMBEDNzMzMzMwEQM3MzMzMzARAzczMzMzMBEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMBEDNzMzMzMwEQM3MzMzMzARAzczMzMzMBEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmFEDNzMzMzMz8PzMzMzMzMx9AZmZmZmZmDkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmFEDNzMzMzMz8PzMzMzMzMx9AZmZmZmZmDkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eel\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"oil","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"oi ...

# %% [markdown]
# ### Hydrogen Balance

# %%
plot_config['chart_config'] = yaml_config['charts']['hydrogen_balance']

fig, df = plot_energy_balance(
    carrier="H2",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_h2,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="035fcbf6-b07f-4d60-907d-36e358e9f231" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("035fcbf6-b07f-4d60-907d-36e358e9f231")) {                    Plotly.newPlot(                        "035fcbf6-b07f-4d60-907d-36e358e9f231",                        [{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmbmP0BmZmZmZuY\u002fQM3MzMzMTEJAzczMzMxMQkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmbmP0BmZmZmZuY\u002fQM3MzMzMTEJAzczMzMxMQkA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Production"}},{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Other industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMAMDNzMzMzMwAwJqZmZmZmQHAmpmZmZmZAcA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMAMDNzMzMzMwAwJqZmZmZmQHAmpmZmZmZAcA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Fuel Cell","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz878zMzMzMzPzvzMzMzMzM\u002fO\u002fMzMzMzMz878="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz878zMzMzMzPzvzMzMzMzM\u002fO\u002fMzMzMzMz878="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"NH3 Synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZEcCamZmZmZkRwDMzMzMzMzDAMzMzMzMzMMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZEcCamZmZmZkRwDMzMzMzMzDAMzMzMzMzMMA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eGH2 balance [TWh\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#836bad","pattern":{"shape":""}},"name":"CH3OH Synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmAsBmZmZmZmYCwDMzMzMzMx3AMzMzMzMzHcA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmAsBmZmZmZmYCwDMzMzMzMx3AMzMzMzMzHcA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"te ...

# %% [markdown]
# ### Hydrogen Installed Capacity

# %%
plot_config['chart_config'] = yaml_config['charts']['hydrogen_capacity']

fig, df = plot_capacity(
    carrier="H2",
    capacity_dict=optimal_capacity_dict,
    config=plot_config,
    rename_function=rename_h2,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="0775f167-234e-4aa6-901f-fbc614976cc1" class="plotly-graph-div" style="height:300px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0775f167-234e-4aa6-901f-fbc614976cc1")) {                    Plotly.newPlot(                        "0775f167-234e-4aa6-901f-fbc614976cc1",                        [{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity [GW\u003csub\u003eH2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzEUAzMzMzMzMXQJqZmZmZmRFAZmZmZmZmFkA="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzEUAzMzMzMzMXQJqZmZmZmRFAZmZmZmZmFkA="},"yaxis":"y","type":"bar","textangle":0},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["4","6","4","6"],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"top center","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzFUAzMzMzMzMbQJqZmZmZmRVAZmZmZmZmGkA="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333, ...

# %% [markdown]
# ### Liquid Fuel Balance

# %%
plot_config['chart_config'] = yaml_config['charts']['liquid_fuel_balance']

fig, df = plot_energy_balance(
    carrier="oil",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_oil,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="e8b139a2-25ce-4f1b-9022-0d0b2c845483" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e8b139a2-25ce-4f1b-9022-0d0b2c845483")) {                    Plotly.newPlot(                        "e8b139a2-25ce-4f1b-9022-0d0b2c845483",                        [{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Fossil fuel import","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMwsX0DNzMzMzCxfQDMzMzMzM19AMzMzMzMzX0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMwsX0DNzMzMzCxfQDMzMzMzM19AMzMzMzMzX0A="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Production"}},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#669db2","pattern":{"shape":""}},"name":"Land transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmbmTsBmZmZmZuZOwGZmZmZm5k7AZmZmZmbmTsA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmbmTsBmZmZmZuZOwGZmZmZm5k7AZmZmZmbmTsA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#39c1cd","pattern":{"shape":""}},"name":"Navigation","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmBsBmZmZmZmYGwGZmZmZmZgbAZmZmZmZmBsA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmBsBmZmZmZmYGwGZmZmZmZgbAZmZmZmZmBsA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Aviation","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmL8BmZmZmZmYvwGZmZmZmZi\u002fAZmZmZmZmL8A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmL8BmZmZmZmYvwGZmZmZmZi\u002fAZmZmZmZmL8A="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#f58220","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMxMMcDNzMzMzEwxwAAAAAAAgDHAAAAAAACAMcA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMxMMcDNzMzMzEwxwAAAAAAAgDHAAAAAAACAMcA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#b ...

# %% [markdown]
# ### CH4 Balance

# %%
plot_config['chart_config'] = yaml_config['charts']['ch4_balance']

fig, df = plot_energy_balance(
    carrier="gas",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_gas,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="47d70115-7306-45e7-9c71-8456cfe85d78" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("47d70115-7306-45e7-9c71-8456cfe85d78")) {                    Plotly.newPlot(                        "47d70115-7306-45e7-9c71-8456cfe85d78",                        [{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Gas import","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMyMTECamZmZmZk1QDMzMzMzU1VAZmZmZmZmREA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMyMTECamZmZmZk1QDMzMzMzU1VAZmZmZmZmREA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Production"}},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAABATMAAAAAAAAA1wGZmZmZmJlXAzczMzMwMRMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAABATMAAAAAAAAA1wGZmZmZmJlXAzczMzMwMRMA="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance [TWh]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZm5r9mZmZmZmbmv2ZmZmZmZua\u002fZmZmZmZm5r8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZm5r9mZmZmZmbmv2ZmZmZmZua\u002fZmZmZmZm5r8="},"yaxis":"y","type":"bar","textangle":0,"legendgrouptitle":{"text":"Consumption"}},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["57","22","85","41"],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"top center","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMwMT0CamZmZmZk6QDMzMzMzk1ZAZmZmZmbmRkA="},"yaxis":"y","type":"scatter"},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["","","",""],"textfont":{"color":"black","size":14,"weight":"bold"},"textposition":"bottom center","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZkZSkAzMzMzM7MwQDMzMzMzE1RAZmZmZmbmQUA="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"o ...

# %% [markdown]
# ### CO2 Capture and Usage

# %%
plot_config['chart_config'] = yaml_config['charts']['co2_stored_balance']

fig, df = plot_energy_balance(
    carrier="co2 stored",
    balance_dict=balance_dict,
    config=plot_config,
    rename_function=rename_co2,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="a34cc797-11dc-4123-a478-7abc7199a9f2" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a34cc797-11dc-4123-a478-7abc7199a9f2")) {                    Plotly.newPlot(                        "a34cc797-11dc-4123-a478-7abc7199a9f2",                        [{"hovertemplate":"variable=Process emissions with CC\u003cbr\u003e=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Process emissions with CC","marker":{"color":"#9467BD","pattern":{"shape":""}},"name":"Process emissions with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA4D8AAAAAAADgP5qZmZmZmfk\u002fMzMzMzMz+z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA4D8AAAAAAADgP5qZmZmZmfk\u002fMzMzMzMz+z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=methanolisation\u003cbr\u003e=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"methanolisation","marker":{"color":"#8C564B","pattern":{"shape":""}},"name":"methanolisation","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA4L8AAAAAAADgv5qZmZmZmfm\u002fmpmZmZmZ+b8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA4L8AAAAAAADgv5qZmZmZmfm\u002fmpmZmZmZ+b8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Carbon capture\u003cbr\u003e=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Carbon capture","marker":{"color":"#E377C2","pattern":{"shape":""}},"name":"Carbon capture","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZub8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZub8="},"yaxis":"y","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolo ...

# %% [markdown]
# ### CO2 Emissions

# %%
plot_config['chart_config'] = yaml_config['charts']['co2_emissions']

fig, df = plot_energy_balance(
    carrier="co2",
    balance_dict=balance_dict,
    config=plot_config,
    save_dir=SDIR
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="c540db47-6a58-42f2-b926-99b690f39089" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c540db47-6a58-42f2-b926-99b690f39089")) {                    Plotly.newPlot(                        "c540db47-6a58-42f2-b926-99b690f39089",                        [{"hovertemplate":"variable=CCGT\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CCGT","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"CCGT","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzJEDNzMzMzMwQQJqZmZmZmSpAMzMzMzMzIEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzJEDNzMzMzMwQQJqZmZmZmSpAMzMzMzMzIEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=OCGT\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OCGT","marker":{"color":"#BCBD22","pattern":{"shape":""}},"name":"OCGT","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz8z+amZmZmZkNQA=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","IR-HBIv1.0+STEELv1.0"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz8z+amZmZmZkNQA=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=aviation oil emissions\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"aviation oil emissions","marker":{"color":"#17BECF","pattern":{"shape":""}},"name":"aviation oil emissions","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMEEDNzMzMzMwQQM3MzMzMzBBAzczMzMzMEEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMEEDNzMzMzMwQQM3MzMzMzBBAzczMzMzMEEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=co2\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"co2","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"co2","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAABgXMAAAAAAAKBTwAAAAAAAAF7AAAAAAACgU8A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAABgXMAAAAAAAKBTwAAAAAAAAF7AAAAAAACgU8A="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=coal\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"coal","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"coal","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmYmQkDNzMzMzMwgQM3MzMzMjEJAZmZmZmZmEkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmYmQkDNzMzMzMwgQM3MzMzMjEJAZmZmZmZmEkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=gas for industry\u003cbr\u003e=%{x}\u003cbr\u003eCO2 emissions [Mt\u003csub\u003eCO2\u003c\u002fsub\u003e]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ga ...

# %% [markdown]
# ### System Costs

# %%
plot_config['chart_config'] = yaml_config['charts'].get('system_costs', {
    'title': 'System Costs',
    'save_name': 'system_costs_billion_eur',
    'chart_type': 'bar_with_negatives'
})
stats_df = pd.concat([costs_dict["capex"], costs_dict["opex"]], axis=0)
df = prepare_dataframe(stats_df, IDX_GROUP, INDEX_LEVELS_TO_DROP, set_scen_col)
df.variable = df.variable.map(rename_costs)
df = df[df["value"] != 0]
df = df.query("scen in @SCEN_FILTER") if SCEN_FILTER else df

fig_kwargs_costs = plot_config['fig_kwargs'].copy()
fig_kwargs_costs['height'] = plot_config['heights']['large']

fig = px.bar(
    df,
    **fig_kwargs_costs,
    color_discrete_map=colors["costs"],
    category_orders={
        "variable": list(colors["costs"].keys()),
        "scen": scen_order
    },
    labels={
        "value": "System costs [billion EUR/year]",
        "year": "",
        "scen": ""
    }
)

chart_type = plot_config['chart_config'].get('chart_type', 'bar') #'bar_with_negatives'
fig = apply_standard_styling(fig, chart_type, plot_config['chart_config'])

save_name = plot_config['chart_config'].get('save_name', 'system_costs')
save_plotly_fig(df, fig, SDIR, f"{IDX_GROUP_NAME}_{save_name}")

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="fa1e4e0f-936a-429b-ba78-42488d1945f4" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fa1e4e0f-936a-429b-ba78-42488d1945f4")) {                    Plotly.newPlot(                        "fa1e4e0f-936a-429b-ba78-42488d1945f4",                        [{"hovertemplate":"variable=Solar\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM7D\u002fNzMzMzMz0P83MzMzMzOw\u002fzczMzMzM9D8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM7D\u002fNzMzMzMz0P83MzMzMzOw\u002fzczMzMzM9D8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=H2 Electrolysis\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA8D9mZmZmZmb2PwAAAAAAAPA\u002fzczMzMzM9D8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA8D9mZmZmZmb2PwAAAAAAAPA\u002fzczMzMzM9D8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=NH3 Synthesis\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NH3 Synthesis","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"NH3 Synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT+amZmZmZnJPw=="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT+amZmZmZnJPw=="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Oil\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oil","marker":{"color":"#C0C0C0","pattern":{"shape":""}},"name":"Oil","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmEEBmZmZmZmYQQGZmZmZmZhBAZmZmZmZmEEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmEEBmZmZmZmYQQGZmZmZmZhBAZmZmZmZmEEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Coal\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coal","marker":{"color":"#454545","pattern":{"shape":""}},"name":"Coal","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzB0CamZmZmZkBQAAAAAAAAAhAAAAAAAAAAEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["Exp-H2v1.0","Exp-H2v1.0-Co2L1.09","IR-HBIv1.0+STEELv1.0","IR-HBIv1.0+STEELv1.0-Co2L1.09"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzB0CamZmZmZkBQAAAAAAAAAhAAAAAAAAAAEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Gas\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs [billion EUR\u002fyear]=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas","orientation" ...
