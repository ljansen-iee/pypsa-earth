# %% [markdown]
# Create summary of statistics (energy balance, optimal capacity, ...) of all runs of multiple config files - independent of Snakemake file.

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import pandas as pd
idx_slice = pd.IndexSlice
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # Comment out for debugging and development
warnings.simplefilter(action='ignore', category=DeprecationWarning) # Comment out for debugging and development
import plotly.express as px
import plotly.graph_objects as go


from plot_helpers import (
    chdir_to_parent_dir,
    read_stats_dict,
    drop_index_levels, 
    update_layout, 
    prepare_dataframe,
    get_supply_demand_from_balance,
    rename_electricity, 
    rename_h2,
    rename_gas,
    rename_oil,
    rename_co2,
    rename_costs,
    rename_to_upper_case,
    colors,
    nice_title,
    save_plotly_fig)

chdir_to_parent_dir()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
run_name_prefix = "H2G_B" # Experiment name

sdir = Path.cwd() / "results"/ f"{run_name_prefix}_summary_20250522"
sdir.mkdir(exist_ok=True, parents=True)

# %%
balance_dict = read_stats_dict("balance_dict", sdir, keys=["AC", "H2", "oil", "gas", "co2 stored", "co2"])
optimal_capacity_dict = read_stats_dict("optimal_capacity_dict", sdir, keys=["AC", "H2"])
costs_dict = read_stats_dict("costs_dict", sdir, keys=["capex", "opex"])
mean_marginal_prices = read_stats_dict("mean_marginal_prices", sdir, keys=["H2 export bus"])

# simplify index for plotting: define a scen_str column and drop all other columns
#NB: the following is specific to the experiment

index_levels_to_drop=["simpl", "clusters", "ll", "opts", "sopts", "discountrate", "demand"]

for key in balance_dict.keys():
    balance_dict[key] = drop_index_levels(balance_dict[key], to_drop=index_levels_to_drop)

for key in optimal_capacity_dict.keys():
    optimal_capacity_dict[key] = drop_index_levels(optimal_capacity_dict[key], to_drop=index_levels_to_drop)
    
for key in costs_dict.keys():
    costs_dict[key] = drop_index_levels(costs_dict[key], to_drop=index_levels_to_drop)
# Out:
# Imported AC from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\balance_dict_AC.csv
# Imported H2 from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\balance_dict_H2.csv
# Imported oil from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\balance_dict_oil.csv
# Imported gas from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\balance_dict_gas.csv
# Imported co2 stored from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\balance_dict_co2 stored.csv
# Imported co2 from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\balance_dict_co2.csv
# Imported AC from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\optimal_capacity_dict_AC.csv
# Imported H2 from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\optimal_capacity_dict_H2.csv
# Imported capex from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\costs_dict_capex.csv
# Imported opex from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\costs_dict_opex.csv
# Imported H2 export bus from C:\Users\ljansen\projects\pypsa-earth-custom\results\H2G_B_summary_20250522\mean_marginal_prices_H2 export bus.csv

# %% [markdown]
# # Plotting

# %%
print(balance_dict["AC"].index.names)
print(balance_dict["AC"].index)
# Out:
# ['run_name_prefix', 'country', 'year', 'h2export']
# MultiIndex([('H2G_B', 'MA', 2030, 10.0)],
#            names=['run_name_prefix', 'country', 'year', 'h2export'])

# %%
# select and define index group (multiindex) for plots: which solutions to show at once

idx_group = idx_slice[["H2G_B"],["MA"],[2030],:]
idx_group_name = ""

print(idx_group_name) 
print(idx_group)
# Out:
# (['H2G_B'], ['MA'], [2030], slice(None, None, None))

# %%
width = 700
heights = {"1": 300,"2": 600,"3": 700,}

fig_kwargs = dict(
    x="scen", 
    y="value", 
    color="variable", 
    facet_col="year", 
    facet_row="country",
    barmode="relative", 
    text="value", 
    #facet_col_wrap=1, facet_col_spacing=0.07,
    width=width, 
    height=heights["2"],
    text_auto =".0f",
)

scen_order = [] # option to specify order of scenarios in the plot

# %% [markdown]
# ## Energy market balance | Electricity

# %%
df = prepare_dataframe(balance_dict["AC"], idx_group)

df.variable = df.variable.map(rename_electricity).map(rename_to_upper_case)

# supply_df = df[df["value"]>=0.01].copy()
# supply_df = supply_df.groupby(["scen","year","variable"], as_index=False).sum()
# #supply_df = supply_df.query("variable not in ['Battery', 'Hydro Power']")
# supply_sums_df = supply_df.groupby(["scen","year"]).sum(numeric_only=True).round(0)
(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
df
# Out:
#    run_name_prefix           scen  year country           variable  value
# 0            H2G_B  0.3MtH2export  2030      MA              Other  -45.8
# 1            H2G_B  0.3MtH2export  2030      MA  Electric vehicles   -1.8
# 2            H2G_B  0.3MtH2export  2030      MA       Gas turbines   12.0
# 9            H2G_B  0.3MtH2export  2030      MA        Agriculture   -4.1
# 10           H2G_B  0.3MtH2export  2030      MA            Battery   -0.6
# 11           H2G_B  0.3MtH2export  2030      MA            Battery    0.6
# 13           H2G_B  0.3MtH2export  2030      MA               Coal    1.5
# 14           H2G_B  0.3MtH2export  2030      MA              Hydro    2.4
# 15           H2G_B  0.3MtH2export  2030      MA           Industry  -16.9
# 18           H2G_B  0.3MtH2export  2030      MA                Oil    4.0
# 19           H2G_B  0.3MtH2export  2030      MA       Wind onshore   47.2
# 20           H2G_B  0.3MtH2export  2030      MA     Rail transport   -0.3
# 21           H2G_B  0.3MtH2export  2030      MA      Power-to-heat   -0.3
# 22           H2G_B  0.3MtH2export  2030      MA      Power-to-heat   -0.9
# 23           H2G_B  0.3MtH2export  2030      MA      Power-to-heat   -0.6
# 24           H2G_B  0.3MtH2export  2030      MA      Power-to-heat   -1.7
# 25           H2G_B  0.3MtH2export  2030      MA              Hydro    0.1
# 26           H2G_B  0.3MtH2export  2030      MA           Commerce   -8.5
# 31           H2G_B  0.3MtH2export  2030      MA           Solar PV   14.4
# 32           H2G_B  0.3MtH2export  2030      MA      Power-to-heat   -0.1
# 35           H2G_B  0.3MtH2export  2030      MA      Power-to-heat   -0.6

# %%
fig_name = "electricity_supply_TWh"
fig = px.bar(
    supply_df, 
    **fig_kwargs,
    labels={"value":"Electricity supply in TWh<sub>el</sub>",
            "year":"",
            "variable":"", 
            "scen":""
            },
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    #facet_col_wrap=1, facet_col_spacing=0.07,
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(supply_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                             value
# scen          year country
# 0.3MtH2export 2030 MA        82.2
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="b2d938ee-04a1-4c09-b480-4c77028f194c" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b2d938ee-04a1-4c09-b480-4c77028f194c")) {                    Plotly.newPlot(                        "b2d938ee-04a1-4c09-b480-4c77028f194c",                        [{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMLEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMLEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZR0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZR0A="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coal","marker":{"color":"#454545","pattern":{"shape":""}},"name":"Coal","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA+D8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+D8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAABEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAABEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAKEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAKEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Battery","marker":{"color":"#836bad","pattern":{"shape":""}},"name":"Battery","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz4z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz4z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oil","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Oil","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAEEA="},"textposition":"inside", ...

# %%
fig_name = "electricity_demand_TWh"
fig = px.bar(
    demand_df, 
    **fig_kwargs,
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    labels={"value":"Electricity demand in TWh<sub>el</sub>","year":"",
            "variable":"", 
            "scen":""},
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(demand_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                             value
# scen          year country
# 0.3MtH2export 2030 MA        82.2
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="b042e54d-2e77-47e1-8266-655abbda1523" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b042e54d-2e77-47e1-8266-655abbda1523")) {                    Plotly.newPlot(                        "b042e54d-2e77-47e1-8266-655abbda1523",                        [{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#f58220","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmbmMEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmbmMEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commerce","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Commerce","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAIUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAIUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","marker":{"color":"#f08591","pattern":{"shape":""}},"name":"Agriculture","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmEEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmEEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rail transport","marker":{"color":"#008598","pattern":{"shape":""}},"name":"Rail transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electric vehicles","marker":{"color":"#a8508c","pattern":{"shape":""}},"name":"Electric vehicles","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM\u002fD8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM\u002fD8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Battery","marker":{"color":"#836bad","pattern":{"shape":""}},"name":"Battery","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz4z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz4z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Other","orientation":"v","showlegend":true,"text":{"dtype":"f8", ...

# %% [markdown]
# ## Energy and feedstock market balance | Hydrogen

# %%
df = prepare_dataframe(balance_dict["H2"], idx_group)
df = df[df["value"]!=0]
df.variable = df.variable.map(rename_h2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "hydrogen_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["hydrogen"],
    category_orders={
        "variable":list(colors["hydrogen"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"H2 balance in TWh","year":"",
            "variable":"", 
            "scen": ""},

)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                             value
# scen          year country
# 0.3MtH2export 2030 MA        11.7
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="3b5e4569-a80e-405c-82e1-8d617b9e19b1" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3b5e4569-a80e-405c-82e1-8d617b9e19b1")) {                    Plotly.newPlot(                        "3b5e4569-a80e-405c-82e1-8d617b9e19b1",                        [{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Land transport","marker":{"color":"#669db2","pattern":{"shape":""}},"name":"Land transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZ+b8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZ+b8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 export","marker":{"color":"#4CC2A6","pattern":{"shape":""}},"name":"H2 export","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAJMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAJMA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shipping","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"Shipping","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZub8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZub8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR CC","marker":{"color":"#BCBD22","pattern":{"shape":""}},"name":"SMR CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmJ0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmJ0A="},"yaxis":"y","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[ ...

# %% [markdown]
# ## Energy and feedstock market balance | Liquid fuel

# %%
df = prepare_dataframe(balance_dict["oil"], idx_group)
df = df[df["value"]!=0]
df.variable = df.variable.map(rename_oil)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "liquid_fuel_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["oil"],
    category_orders={
        "variable":list(colors["oil"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"Liquid fuel balance in TWh","year":"",
            "variable":"", 
            "scen":""},

)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                             value
# scen          year country
# 0.3MtH2export 2030 MA       158.2
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="b9b82524-89dd-40da-bf2f-608e5cc9e847" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b9b82524-89dd-40da-bf2f-608e5cc9e847")) {                    Plotly.newPlot(                        "b9b82524-89dd-40da-bf2f-608e5cc9e847",                        [{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fossil fuel import","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Fossil fuel import","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmbGY0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmbGY0A="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Land transport","marker":{"color":"#669db2","pattern":{"shape":""}},"name":"Land transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMwMTsA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMwMTsA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maritime","marker":{"color":"#39c1cd","pattern":{"shape":""}},"name":"Maritime","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmCsA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmCsA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aviation","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Aviation","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZL8A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZL8A="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#f58220","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMwMQMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMwMQMA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commerce","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Commerce","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM9L8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM9L8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Residential","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Residential","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmQsA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmQsA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eLiquid f ...

# %% [markdown]
# ## Energy and feedstock market balance | CH4

# %%
df = prepare_dataframe(balance_dict["gas"], idx_group)
df = df[df["value"]!=0]
df.variable = df.variable.map(rename_gas)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "CH4_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["gas"],
    category_orders={
        "variable":list(colors["gas"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"CH4 balance in TWh","year":"",
            "variable":"", 
            "scen":""},

)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                             value
# scen          year country
# 0.3MtH2export 2030 MA        44.6
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="b4895a27-cbd2-4417-bfeb-2b703229f899" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b4895a27-cbd2-4417-bfeb-2b703229f899")) {                    Plotly.newPlot(                        "b4895a27-cbd2-4417-bfeb-2b703229f899",                        [{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas import","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Gas import","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZlZRkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZlZRkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzOzNMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzOzNMA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM9L8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM9L8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas boiler","marker":{"color":"#d6a67c","pattern":{"shape":""}},"name":"Gas boiler","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA+L8zMzMzMzMLwGZmZmZmZua\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export","0.3MtH2export","0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA+L8zMzMzMzMLwGZmZmZmZua\u002f"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"steam methane reforming CC","marker":{"color":"#17BECF","pattern":{"shape":""}},"name":"steam methane reforming CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAMcA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAMcA="},"yaxis":"y","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tick ...

# %% [markdown]
# ## Energy and feedstock market balance | CO2

# %%
df = prepare_dataframe(balance_dict["co2 stored"], idx_group)
df = df[df["value"]!=0]

df.variable = df.variable.map(rename_co2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["co2"],
    category_orders={
        "variable":list(colors["gas"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"CO<sub>2</sub> Capture (+) and Usage (-) in Mt","year":"","variable":"", "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_CO2_capture_and_usage_Mt")
# Out:
# Totals per scenario and year:                             value
# scen          year country
# 0.3MtH2export 2030 MA        19.1
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="d3d5e7c4-bebd-4fe9-bd5e-7b0a8e7ded70" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d3d5e7c4-bebd-4fe9-bd5e-7b0a8e7ded70")) {                    Plotly.newPlot(                        "d3d5e7c4-bebd-4fe9-bd5e-7b0a8e7ded70",                        [{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR CC","marker":{"color":"#8C564B","pattern":{"shape":""}},"name":"SMR CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAACEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAACEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"co2 stored","marker":{"color":"#E377C2","pattern":{"shape":""}},"name":"co2 stored","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZkZM8A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZkZM8A="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Process emissions with CC","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Process emissions with CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZkZMEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZkZMEA="},"yaxis":"y","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#44015 ...

# %% [markdown]
# ## CO2 atmosphere balance

# %%
balance_dict.keys()
# Out:
# dict_keys(['AC', 'H2', 'oil', 'gas', 'co2 stored', 'co2'])

# %%
df = prepare_dataframe(balance_dict["co2"], idx_group)

#df.variable = df.variable.map(rename_co2)

# supply_df = df[df["value"]>=0.01].copy()
# supply_df = supply_df.groupby(["scen","year","variable"], as_index=False).sum()
# #supply_df = supply_df.query("variable not in ['Battery', 'Hydro Power']")
# supply_sums_df = supply_df.groupby(["scen","year"]).sum(numeric_only=True).round(0)
(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
df
# Out:
#    run_name_prefix           scen  year country  \
# 0            H2G_B  0.3MtH2export  2030      MA
# 4            H2G_B  0.3MtH2export  2030      MA
# 6            H2G_B  0.3MtH2export  2030      MA
# 8            H2G_B  0.3MtH2export  2030      MA
# 9            H2G_B  0.3MtH2export  2030      MA
# 11           H2G_B  0.3MtH2export  2030      MA
# 12           H2G_B  0.3MtH2export  2030      MA
# 13           H2G_B  0.3MtH2export  2030      MA
# 14           H2G_B  0.3MtH2export  2030      MA
# 15           H2G_B  0.3MtH2export  2030      MA
# 16           H2G_B  0.3MtH2export  2030      MA
# 17           H2G_B  0.3MtH2export  2030      MA
# 18           H2G_B  0.3MtH2export  2030      MA
# 19           H2G_B  0.3MtH2export  2030      MA
# 22           H2G_B  0.3MtH2export  2030      MA
# 26           H2G_B  0.3MtH2export  2030      MA
#
#                                   variable  value
# 0                                     CCGT    4.1
# 4                                   SMR CC    0.3
# 6                                      co2  -53.0
# 8                                     coal    1.6
# 9                         gas for industry    0.3
# 11                 industry coal emissions    0.1
# 12                  industry oil emissions    8.3
# 13            land transport oil emissions   15.5
# 14                                     oil    2.9
# 15                           oil emissions   16.0
# 16                       process emissions    0.1
# 17                    process emissions CC    1.8
# 18            residential rural gas boiler    0.3
# 19  residential urban decentral gas boiler    0.7
# 22                  shipping oil emissions    0.8
# 26                urban central gas boiler    0.1

# %%
fig_name = "co2_emissions_mt"
fig = px.bar(
    df, 
    **fig_kwargs,
    labels={"value":"CO2 emissions in Mt<sub>CO2</sub>",
            "year":"",
            "variable":"", 
            "scen":""
            },
    color_discrete_map=colors["co2"],
    category_orders={
        "variable":list(colors["co2"].keys()),
        "scen": scen_order
        },
    #facet_col_wrap=1, facet_col_spacing=0.07,
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(supply_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                             value
# scen          year country
# 0.3MtH2export 2030 MA        52.9
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="ec2c1f28-4533-47d1-87f5-f0c93c0de7d2" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ec2c1f28-4533-47d1-87f5-f0c93c0de7d2")) {                    Plotly.newPlot(                        "ec2c1f28-4533-47d1-87f5-f0c93c0de7d2",                        [{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CCGT","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"CCGT","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmEEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmEEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR CC","marker":{"color":"#BCBD22","pattern":{"shape":""}},"name":"SMR CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"co2","marker":{"color":"#17BECF","pattern":{"shape":""}},"name":"co2","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACASsA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAACASsA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"coal","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"coal","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZ+T8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZ+T8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"gas for industry","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"gas for industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"industry coal emissions","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"industry coal emissions","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"industry oil emissions","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"industry oil emissions","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZIEA="},"text ...

# %% [markdown]
# ## Installed Capacities | Electricity

# %%
df = prepare_dataframe(optimal_capacity_dict["AC"], idx_group)
df = df[df["value"]<1e6] #drop loadshedding capacity
df.variable = df.variable.map(rename_electricity).map(rename_to_upper_case)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "electricity_installed_capacity_GW"
fig = px.bar(
    df, 
    **fig_kwargs,
    #barmode="stack",
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    #range_y=(0,supply_sum_df.max().value*1.1),
    labels={"value":"Installed capacity in GW<sub>el</sub>","year":"",
            #"variable":"",
            "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                             value
# scen          year country
# 0.3MtH2export 2030 MA        42.6
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="e8ee2449-2343-473b-a9d8-508a6f778bef" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e8ee2449-2343-473b-a9d8-508a6f778bef")) {                    Plotly.newPlot(                        "e8ee2449-2343-473b-a9d8-508a6f778bef",                        [{"hovertemplate":"variable=Solar PV\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZJ0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZJ0A="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Wind onshore\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZM0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZM0A="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Coal\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coal","marker":{"color":"#454545","pattern":{"shape":""}},"name":"Coal","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAEEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAEEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Hydro\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZ6T8zMzMzMzPzPwAAAAAAAOA\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export","0.3MtH2export","0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZ6T8zMzMzMzPzPwAAAAAAAOA\u002f"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Gas turbines\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMDEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMDEA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Battery\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Battery","marker":{"color":"#836bad","pattern":{"shape":""}},"name":"Battery","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz0z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Oil\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capac ...

# %%
df = prepare_dataframe(optimal_capacity_dict["H2"], idx_group)
df = df[df["value"]<1e6] #drop loadshedding capacity
df.variable = df.variable.map(rename_h2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "hydrogen_installed_capacity_GW"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map={"H2 Electrolysis":"#179c7d"},
    category_orders={
        #"variable":list(colors["gas"].keys())
        "scen": scen_order
        },
    labels={"value":"Installed capacity in GW<sub>H2</sub>","year":"","variable":"","scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                             value
# scen          year country
# 0.3MtH2export 2030 MA         1.3
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="16430811-6dde-432d-af74-ebddb36cbff3" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("16430811-6dde-432d-af74-ebddb36cbff3")) {                    Plotly.newPlot(                        "16430811-6dde-432d-af74-ebddb36cbff3",                        [{"hovertemplate":"=%{x}\u003cbr\u003ecountry=MA\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR CC","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"SMR CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM9D8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM9D8="},"yaxis":"y","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"ou ...

# %%
stats_df = pd.concat([costs_dict["capex"],costs_dict["opex"]],axis=0)
df = prepare_dataframe(stats_df, idx_group)
df.variable = df.variable.map(rename_costs) # ToDo rename important cost components
df = df.groupby(["run_name_prefix", "scen", "year", "country", "variable"], as_index=False).sum().round(1)
df = df[df["value"]!=0]

# (supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df, threshold=0., round=1)

# %%
fig_name = "system_costs_billion_eur" # expenditure and export revenue
fig_kwargs["height"] = heights["3"]
fig_kwargs["text_auto"] = ".1f"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["costs"],
    category_orders={
        "variable":list(colors["costs"].keys()),
        #"scen": scen_order
        },
    facet_col_spacing=0.1,
    labels={"value":"System costs in billion EUR20XX/year","year":"", 
            #"variable":"", 
            "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_installed_capacity_AC_GW")
# Out:
# Totals per scenario and year:                             value
# scen          year country
# 0.3MtH2export 2030 MA         1.3
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="50f88cee-2f51-45e2-82e6-73ba741445f6" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("50f88cee-2f51-45e2-82e6-73ba741445f6")) {                    Plotly.newPlot(                        "50f88cee-2f51-45e2-82e6-73ba741445f6",                        [{"hovertemplate":"variable=Solar\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA4D8="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA4D8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Wind\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz8z8="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz8z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=H2 export\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 export","marker":{"color":"#7c154d","pattern":{"shape":""}},"name":"H2 export","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZyb8="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZyb8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Transmission line\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Transmission line","marker":{"color":"#4cc2a6","pattern":{"shape":""}},"name":"Transmission line","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZm5j8="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZm5j8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Oil\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oil","marker":{"color":"#C0C0C0","pattern":{"shape":""}},"name":"Oil","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Coal\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coal","marker":{"color":"#454545","pattern":{"shape":""}},"name":"Coal","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZm9j8="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["0.3MtH2export"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZm9j8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Gas\u003cbr\u003ecountry=MA\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata": ...

# %% [markdown]
# ## Relative costs
#
# costs / total energy consumption

# %% [markdown]
# ## Water consumption

# %% [markdown]
# ## Marginal prices | H2 export price

# %%
print(mean_marginal_prices["H2 export bus"])
# Out:
#                                                                                                   H2 export bus
# run_name_prefix country year simpl clusters ll   opts     sopts discountrate demand     h2export
# H2G_B           MA      2030 NaN   3flex    copt Co2L0.83 3h    0.071        MA-GNZ-IEE 10.0           52.69488

# %%
df = prepare_dataframe(
    mean_marginal_prices["H2 export bus"], 
    idx_slice[["H2G_A"],:,[2035],:]
)

df = df.query("variable in ['H2 export bus']")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '['H2G_A']' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\multi.py:3499, in MultiIndex.get_locs(self, seq)
#    3498 try:
# -> 3499     lvl_indexer = self._get_level_indexer(k, level=i, indexer=indexer)
#    3500 except (InvalidIndexError, TypeError, KeyError) as err:
#    3501     # InvalidIndexError e.g. non-hashable, fall back to treating
#    3502     #  this as a sequence of labels
#    3503     # KeyError it can be ambiguous if this is a label or sequence
#    3504     #  of labels
#    3505     #  github.com/pandas-dev/pandas/issues/39424#issuecomment-871626708
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\multi.py:3391, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3390 else:
# -> 3391     idx = self._get_loc_single_level_index(level_index, key)
#    3393     if level > 0 or self._lexsort_depth == 0:
#    3394         # Desired level is not sorted
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\multi.py:2980, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2979 else:
# -> 2980     return level_index.get_loc(key)
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\base.py:3817, in Index.get_loc(self, key)
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
# -> 3817     self._check_indexing_error(key)
#    3818     raise
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\base.py:6059, in Index._check_indexing_error(self, key)
#    6056 if not is_scalar(key):
#    6057     # if key is not a scalar, directly raise an error (the code below
#    6058     # would convert to numpy arrays and raise later any way) - GH29926
# -> 6059     raise InvalidIndexError(key)
#
# InvalidIndexError: ['H2G_A']
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'H2G_A'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df = prepare_dataframe(
#       2     mean_marginal_prices["H2 export bus"],
#       3     idx_slice[["H2G_A"],:,[2035],:]
#       4 )
#       6 df = df.query("variable in ['H2 export bus']")
#
# File c:\Users\ljansen\projects\pypsa-earth-custom\post_processing\plot_helpers.py:126, in prepare_dataframe(stats_df, idx_group, round, drop_zero)
#     125 def prepare_dataframe(stats_df, idx_group, round=1, drop_zero=True):
# --> 126     df = stats_df.copy().loc[idx_group].reset_index()
#     127     df = set_scen_col_for_h2g_a(df)
#     128     df = df.melt(id_vars=["run_name_prefix", "scen", "year", "country"]).groupby(
#     129         ["run_name_prefix", "scen", "year", "country", "variable"], as_index=False
#     130     ).sum().round(round)
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexing.py:1041, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1039 # we may have a nested tuples indexer here
#    1040 if self._is_nested_tuple_indexer(tup):
# -> 1041     return self._getitem_nested_tuple(tup)
#    1043 # we maybe be using a tuple to represent multiple dimensions here
#    1044 ax0 = self.obj._get_axis(0)
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexing.py:1140, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1137     # this is a series with a multi-index specified a tuple of
#    1138     # selectors
#    1139     axis = self.axis or 0
# -> 1140     return self._getitem_axis(tup, axis=axis)
#    1142 # handle the multi-axis by taking sections and reducing
#    1143 # this is iterative
#    1144 obj = self.obj
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexing.py:1424, in _LocIndexer._getitem_axis(self, key, axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
# -> 1424     locs = labels.get_locs(key)
#    1425     indexer: list[slice | npt.NDArray[np.intp]] = [slice(None)] * self.ndim
#    1426     indexer[axis] = locs
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\multi.py:3513, in MultiIndex.get_locs(self, seq)
#    3509     raise err
#    3510 # GH 39424: Ignore not founds
#    3511 # GH 42351: No longer ignore not founds & enforced in 2.0
#    3512 # TODO: how to handle IntervalIndex level? (no test cases)
# -> 3513 item_indexer = self._get_level_indexer(
#    3514     x, level=i, indexer=indexer
#    3515 )
#    3516 if lvl_indexer is None:
#    3517     lvl_indexer = _to_bool_indexer(item_indexer)
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\multi.py:3391, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3388         return slice(i, j, step)
#    3390 else:
# -> 3391     idx = self._get_loc_single_level_index(level_index, key)
#    3393     if level > 0 or self._lexsort_depth == 0:
#    3394         # Desired level is not sorted
#    3395         if isinstance(idx, slice):
#    3396             # test_get_loc_partial_timestamp_multiindex
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\multi.py:2980, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2978     return -1
#    2979 else:
# -> 2980     return level_index.get_loc(key)
#
# File c:\Users\ljansen\miniforge3\envs\pypsa-earth-vis\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'H2G_A'

# %%
def marginal_price_dumbbell_fig(df, year):

    df = df.copy()
    df = df[df.year==year]
    countries = df.sort_values(by=["value"], ascending=False)["country"]

    data = {"line_x": [], "line_y": [], "0.1MtH2export": [], "0.7MtH2export": [], "colors": [], "years": [], "countries": []}

    for country in countries:
        data["0.1MtH2export"].extend([df.loc[(df.scen == "0.1MtH2export") & (df.country == country)]["value"].values[0]])
        data["0.7MtH2export"].extend([df.loc[(df.scen == "0.7MtH2export") & (df.country == country)]["value"].values[0]])
        data["line_x"].extend(
            [
                df.loc[(df.scen == "0.1MtH2export") & (df.country == country)]["value"].values[0],
                df.loc[(df.scen == "0.7MtH2export") & (df.country == country)]["value"].values[0],
                None,
            ]
        )
        data["line_y"].extend([country, country, None]),

    fig = go.Figure(
        data=[
            go.Scatter(
                x=data["line_x"],
                y=data["line_y"],
                mode="lines",
                showlegend=False,
                marker=dict(
                    color="grey"
                )
            ),
            go.Scatter(
                x=data["0.1MtH2export"],
                y=countries,
                mode="markers+text",
                name="0.1MtH2export",
                text=data["0.1MtH2export"],            
                textposition="top center",
                texttemplate="%{text:.1f}",
                textfont=dict(size=11),
                marker=dict(
                    color="#A6BCC9",
                    size=13
                )

            ),
            go.Scatter(
                x=data["0.7MtH2export"],
                y=countries,
                mode="markers+text",
                name="0.7MtH2export",
                text=data["0.7MtH2export"],
                textposition="top center",
                texttemplate="%{text:.1f}",
                textfont=dict(size=11),
                marker=dict(
                    color="#179c7d",
                    size=13
                )
            ),
        ]
    )

    fig.update_layout(
        title=dict(text=nice_title(f"Marginal price for H2 at export port in {year}", 
                                   "Per country and H2 export volume in €/MWh_H2_LHV")),
        width=800,
        height=500,
        legend_itemclick=False
    )
    return fig

fig = marginal_price_dumbbell_fig(df, year=2035)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="b45a25ff-a0d0-46a1-9f98-f27256720b97" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b45a25ff-a0d0-46a1-9f98-f27256720b97")) {                    Plotly.newPlot(                        "b45a25ff-a0d0-46a1-9f98-f27256720b97",                        [{"marker":{"color":"grey"},"mode":"lines","showlegend":false,"x":[93.4341638755692,97.86179098600832,null,86.77888154091825,97.82619699034407,null,86.77888154091825,97.82619699034407,null,93.4341638755692,97.86179098600832,null,51.38180605928615,94.26358042552071,null,93.4341638755692,97.86179098600832,null,86.77888154091825,97.82619699034407,null,51.38180605928615,94.26358042552071,null],"y":["EG","EG",null,"NA","NA",null,"NA","NA",null,"EG","EG",null,"MA","MA",null,"EG","EG",null,"NA","NA",null,"MA","MA",null],"type":"scatter"},{"marker":{"color":"#A6BCC9","size":13},"mode":"markers+text","name":"0.1MtH2export","text":["93.4341638755692","86.77888154091825","86.77888154091825","93.4341638755692","51.38180605928615","93.4341638755692","86.77888154091825","51.38180605928615"],"textfont":{"size":11},"textposition":"top center","texttemplate":"%{text:.1f}","x":[93.4341638755692,86.77888154091825,86.77888154091825,93.4341638755692,51.38180605928615,93.4341638755692,86.77888154091825,51.38180605928615],"y":["EG","NA","NA","EG","MA","EG","NA","MA"],"type":"scatter"},{"marker":{"color":"#179c7d","size":13},"mode":"markers+text","name":"0.7MtH2export","text":["97.86179098600832","97.82619699034407","97.82619699034407","97.86179098600832","94.26358042552071","97.86179098600832","97.82619699034407","94.26358042552071"],"textfont":{"size":11},"textposition":"top center","texttemplate":"%{text:.1f}","x":[97.86179098600832,97.82619699034407,97.82619699034407,97.86179098600832,94.26358042552071,97.86179098600832,97.82619699034407,94.26358042552071],"y":["EG","NA","NA","EG","MA","EG","NA","MA"],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"color ...

# %%
fig = marginal_price_dumbbell_fig(df, year=2050)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="66c0621e-de65-4995-abc1-e9270da0e66e" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("66c0621e-de65-4995-abc1-e9270da0e66e")) {                    Plotly.newPlot(                        "66c0621e-de65-4995-abc1-e9270da0e66e",                        [{"marker":{"color":"grey"},"mode":"lines","showlegend":false,"x":[],"y":[],"type":"scatter"},{"marker":{"color":"#A6BCC9","size":13},"mode":"markers+text","name":"0.1MtH2export","text":[],"textfont":{"size":11},"textposition":"top center","texttemplate":"%{text:.1f}","x":[],"y":[],"type":"scatter"},{"marker":{"color":"#179c7d","size":13},"mode":"markers+text","name":"0.7MtH2export","text":[],"textfont":{"size":11},"textposition":"top center","texttemplate":"%{text:.1f}","x":[],"y":[],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlin ...
