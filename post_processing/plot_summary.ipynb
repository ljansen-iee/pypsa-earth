# %% [markdown]
# Plot the summary of statistics (energy balance, optimal capacity, ...)
#
# **Prerequisites**
#
# * Execute "make_stats_dict.py" before using this notebook. The script make_stats_dict creates csv for the metrics for all runs of multiple config files.
# * Install the environment envs/pypsa-earth-vis.yaml

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import pandas as pd
idx_slice = pd.IndexSlice
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # Comment out for debugging and development
warnings.simplefilter(action='ignore', category=DeprecationWarning) # Comment out for debugging and development
import plotly.express as px

from plot_helpers import (
    chdir_to_parent_dir,
    read_stats_dict,
    drop_index_levels, 
    update_layout, 
    prepare_dataframe,
    get_supply_demand_from_balance,
    rename_electricity, 
    rename_h2,
    rename_gas,
    rename_oil,
    rename_co2,
    rename_costs,
    rename_to_upper_case,
    colors,
    nice_title,
    save_plotly_fig)

chdir_to_parent_dir()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def add_production_consumption_legend_groups(fig, df):
    """
    Add legend groups for Production (positive values) and Consumption (negative values).
    
    Parameters:
    -----------
    fig : plotly.graph_objects.Figure
        The plotly figure to modify
    df : pandas.DataFrame
        The dataframe containing the data with 'variable' and 'value' columns
    
    Returns:
    --------
    fig : plotly.graph_objects.Figure
        The modified figure with legend groups
    """
    # Add legend groups for Production (positive values) and Consumption (negative values)
    for trace in fig.data:
        # Get the variable name from the trace
        variable_name = trace.name
        
        # Check if this variable typically has positive or negative values in the data
        variable_data = df[df['variable'] == variable_name]['value']
        
        if len(variable_data) > 0:
            # Determine if this variable is primarily production (positive) or consumption (negative)
            avg_value = variable_data.mean()
            
            if avg_value > 0:
                trace.legendgroup = "Production"
                trace.legendgrouptitle = {"text": "Production"}
            else:
                trace.legendgroup = "Consumption" 
                trace.legendgrouptitle = {"text": "Consumption"}
    
    return fig

# %%
run_name_prefix = "DKS" # Experiment name

sdir = Path.cwd() / "results"/ f"{run_name_prefix}v1_summary"
sdir.mkdir(exist_ok=True, parents=True)

# %%
balance_dict = read_stats_dict("balance_dict", sdir, keys=["AC", "H2", "oil", "gas", "co2 stored", "co2"])
optimal_capacity_dict = read_stats_dict("optimal_capacity_dict", sdir, keys=["AC", "H2"])
costs_dict = read_stats_dict("costs_dict", sdir, keys=["capex", "opex"])

# simplify index for plotting: define a scen_str column and drop all other columns
#NB: the following is specific to the experiment

index_levels_to_drop=["simpl", "clusters", "ll", "opts", "discountrate"] #, , "demand" "sopts"


for key in balance_dict.keys():
    balance_dict[key] = drop_index_levels(balance_dict[key], to_drop=index_levels_to_drop)

for key in optimal_capacity_dict.keys():
    optimal_capacity_dict[key] = drop_index_levels(optimal_capacity_dict[key], to_drop=index_levels_to_drop)
    
for key in costs_dict.keys():
    costs_dict[key] = drop_index_levels(costs_dict[key], to_drop=index_levels_to_drop)
# Out:
# Imported AC from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKSv1_summary\balance_dict_AC.csv
# Imported H2 from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKSv1_summary\balance_dict_H2.csv
# Imported oil from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKSv1_summary\balance_dict_oil.csv
# Imported gas from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKSv1_summary\balance_dict_gas.csv
# Imported co2 stored from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKSv1_summary\balance_dict_co2 stored.csv
# Imported co2 from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKSv1_summary\balance_dict_co2.csv
# Imported AC from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKSv1_summary\optimal_capacity_dict_AC.csv
# Imported H2 from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKSv1_summary\optimal_capacity_dict_H2.csv
# Imported capex from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKSv1_summary\costs_dict_capex.csv
# Imported opex from C:\Users\ljansen\projects\pypsa-earth-custom\results\DKSv1_summary\costs_dict_opex.csv

# %%
# def set_scen_col(df):
#     """
#     Set combined scenario str (for plots).
#     NB: This is specific to the experiment and should be adapted for other experiments.
#     """
#     df = df.copy()

#     df["scen"] = df["eopts"] + "+" + df["sopts"]
#     df = df.drop(columns=["eopts", "sopts"])
#     #df["scen"] = df.apply(lambda row: "_".join([f"{col}_{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)
#     #df["scen"] = df.apply(lambda row: "_".join([f"{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)

#     return df

def set_scen_col(df):
    """
    Set combined scenario str (for plots).
    NB: This is specific to the experiment and should be adapted for other experiments.
    """
    df = df.copy()
    
    # Set base scen value based on 'demand'
    scen = df["demand"].map({"RF": "AB", "EL": "AT"})
    # Add export info
    export_info = ""
    # Add export info based on 'eopts', handling NaN and string values
    export_info = df["eopts"].apply(
        lambda x: "50%Exp" if isinstance(x, str) and "v0.5" in x
        else ("NoExp" if pd.isna(x) or str(x) == "" else "100%Exp")
    )
    # Combine
    df["scen"] = scen + export_info.replace("", "", regex=False).apply(lambda x: f"+{x}" if x else "") + df["sopts"].replace("144H", "", regex=False)
    df = df.drop(columns=["eopts", "sopts", "demand"])
    #df["scen"] = df.apply(lambda row: "_".join([f"{col}_{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)
    #df["scen"] = df.apply(lambda row: "_".join([f"{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)

    return df

# %% [markdown]
# # Plotting

# %%
print(balance_dict["AC"].index.names)
print(balance_dict["AC"].index)
# Out:
# ['run_name_prefix', 'run_name', 'country', 'year', 'sopts', 'demand', 'eopts']
# MultiIndex([('DKS', 'DKS_EG_2030', 'EG', 2030, '144H', 'RF', ...),
#             ('DKS', 'DKS_EG_2030', 'EG', 2030, '144H', 'RF', ...),
#             ('DKS', 'DKS_EG_2030', 'EG', 2030, '144H', 'RF', ...),
#             ('DKS', 'DKS_EG_2030', 'EG', 2030, '144H', 'EL', ...),
#             ('DKS', 'DKS_EG_2030', 'EG', 2030, '144H', 'EL', ...),
#             ('DKS', 'DKS_EG_2030', 'EG', 2030, '144H', 'EL', ...)],
#            names=['run_name_prefix', 'run_name', 'country', 'year', 'sopts', 'demand', 'eopts'])

# %%
width = 700
heights = {"1": 300,"2": 600,"3": 700,}

fig_kwargs = dict(
    x="scen", 
    y="value", 
    color="variable", 
    facet_col="year", 
    # facet_row="run_name",
    barmode="relative", 
    text="value", 
    #facet_col_wrap=1, facet_col_spacing=0.07,
    width=width, 
    height=heights["2"],
    text_auto =".0f",
)

scen_order = ["AB+50%Exp", "AB+100%Exp", "AT+50%Exp", "AT+NoExp"] # option to specify order of scenarios in the plot

# %%
# balance_dict["gas"].query("year == 2050 and country == 'ZA'").T

# %%
# balance_dict["co2 stored"].query("year == 2050 and country == 'ZA'").T

# %%
# select and define index group (multiindex) for plots: which solutions to show at once

idx_group = idx_slice[["DKS"],:,["EG"],[2030],["144H"]]
idx_group_name = ""

print(idx_group_name) 
print(idx_group)

scen_filter = ["AB+50%Exp", "AB+100%Exp", "AT+50%Exp", "AT+NoExp"]
# Out:
# (['DKS'], slice(None, None, None), ['EG'], [2030], ['144H'])

# %% [markdown]
# ## Energy market balance | Electricity

# %%
df = prepare_dataframe(balance_dict["AC"], idx_group, set_scen_col, rename_function=rename_electricity)
df.variable = df.variable.map(rename_to_upper_case)
df = df.query("scen in @scen_filter")

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
df.scen.unique()
# Out:
# array(['AB+100%Exp', 'AB+50%Exp', 'AT+50%Exp', 'AT+NoExp'], dtype=object)

# %%
fig_name = "electricity_supply_TWh"
fig = px.bar(
    supply_df, 
    **fig_kwargs,
    labels={"value":"Electricity supply in TWh<sub>el</sub>",
            "year":"",
            "variable":"", 
            "scen":""
            },
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    #facet_col_wrap=1, facet_col_spacing=0.07,
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)

fig.show()

#save_plotly_fig(supply_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG       391.1
#                             AB+50%Exp  2030 EG       352.3
#                             AT+50%Exp  2030 EG       372.4
#                             AT+NoExp   2030 EG       333.6
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="63f0f0d4-7e62-4e94-9175-b2ae6d3d8450" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("63f0f0d4-7e62-4e94-9175-b2ae6d3d8450")) {                    Plotly.newPlot(                        "63f0f0d4-7e62-4e94-9175-b2ae6d3d8450",                        [{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmxcUCamZmZmTlvQGZmZmZmtnBAMzMzMzNTbUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmxcUCamZmZmTlvQGZmZmZmtnBAMzMzMzNTbUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMGkAzMzMzMzMbQM3MzMzMzBpAMzMzMzMzG0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMGkAzMzMzMzMbQM3MzMzMzBpAMzMzMzMzG0A="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMFkDNzMzMzMwWQM3MzMzMzBZAzczMzMzMFkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMFkDNzMzMzMwWQM3MzMzMzBZAzczMzMzMFkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nuclear","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Nuclear","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAADAREAzMzMzM7NEQAAAAAAAwERAZmZmZmamREA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAADAREAzMzMzM7NEQAAAAAAAwERAZmZmZmamREA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMwMS0DNzMzMzExIQM3MzMzMjElAzczMzMxMRkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMwMS0DNzMzMzExIQM3MzMzMjElAzczMzMxMRkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity supply in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oil","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Oil","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz4z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz4z8="},"yaxis":"y","type":"bar","textangle":0}],                        {"template ...

# %%
fig_name = "electricity_demand_TWh"
fig = px.bar(
    demand_df, 
    **fig_kwargs,
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    labels={"value":"Electricity demand in TWh<sub>el</sub>","year":"",
            "variable":"", 
            "scen":""},
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(demand_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG       391.3
#                             AB+50%Exp  2030 EG       352.4
#                             AT+50%Exp  2030 EG       372.5
#                             AT+NoExp   2030 EG       333.7
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="11484a5e-1a58-4a7f-9088-6a09c5ab29ba" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("11484a5e-1a58-4a7f-9088-6a09c5ab29ba")) {                    Plotly.newPlot(                        "11484a5e-1a58-4a7f-9088-6a09c5ab29ba",                        [{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#f58220","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmYmU0BmZmZmZiZTQJqZmZmZOVtAmpmZmZk5W0A="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmYmU0BmZmZmZiZTQJqZmZmZOVtAmpmZmZk5W0A="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Commerce","marker":{"color":"#b2d235","pattern":{"shape":""}},"name":"Commerce","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAATUAAAAAAAABNQAAAAAAAAE1AAAAAAAAATUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAATUAAAAAAAABNQAAAAAAAAE1AAAAAAAAATUA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ammonia synthesis","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Ammonia synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzD0BmZmZmZmb+P2ZmZmZmZv4\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzD0BmZmZmZmb+P2ZmZmZmZv4\u002f"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","marker":{"color":"#f08591","pattern":{"shape":""}},"name":"Agriculture","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZIkCamZmZmZkiQJqZmZmZmSJAmpmZmZmZIkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZIkCamZmZmZkiQJqZmZmZmSJAmpmZmZmZIkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rail transport","marker":{"color":"#008598","pattern":{"shape":""}},"name":"Rail transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz0z8zMzMzMzPTPzMzMzMzM9M\u002fMzMzMzMz0z8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz0z8zMzMzMzPTPzMzMzMzM9M\u002fMzMzMzMz0z8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eElectricity demand in TWh\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electric vehicles","marker":{"color":"#a8508c","pattern":{"shape":""}},"name":"Electric vehicles","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAABEAAAAAAAAAEQJqZmZmZmQ1AmpmZmZmZDUA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"d ...

# %% [markdown]
# ## Energy and feedstock market balance | Hydrogen

# %%
df = prepare_dataframe(balance_dict["H2"], idx_group, set_scen_col, rename_function=rename_h2)
df = df[df["value"]!=0]
df = df.query("scen in @scen_filter")

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
df
# Out:
#    run_name_prefix     run_name        scen  year country           variable  \
# 0              DKS  DKS_EG_2030  AB+100%Exp  2030      EG  Ammonia synthesis
# 1              DKS  DKS_EG_2030  AB+100%Exp  2030      EG    H2 Electrolysis
# 3              DKS  DKS_EG_2030  AB+100%Exp  2030      EG          H2 export
# 4              DKS  DKS_EG_2030  AB+100%Exp  2030      EG           Industry
# 6              DKS  DKS_EG_2030  AB+100%Exp  2030      EG    Power-to-liquid
# 7              DKS  DKS_EG_2030  AB+100%Exp  2030      EG                SMR
# 8              DKS  DKS_EG_2030  AB+100%Exp  2030      EG             SMR CC
# 9              DKS  DKS_EG_2030  AB+100%Exp  2030      EG           Shipping
# 11             DKS  DKS_EG_2030   AB+50%Exp  2030      EG  Ammonia synthesis
# 12             DKS  DKS_EG_2030   AB+50%Exp  2030      EG    H2 Electrolysis
# 14             DKS  DKS_EG_2030   AB+50%Exp  2030      EG          H2 export
# 15             DKS  DKS_EG_2030   AB+50%Exp  2030      EG           Industry
# 17             DKS  DKS_EG_2030   AB+50%Exp  2030      EG    Power-to-liquid
# 18             DKS  DKS_EG_2030   AB+50%Exp  2030      EG                SMR
# 19             DKS  DKS_EG_2030   AB+50%Exp  2030      EG             SMR CC
# 20             DKS  DKS_EG_2030   AB+50%Exp  2030      EG           Shipping
# 44             DKS  DKS_EG_2030   AT+50%Exp  2030      EG  Ammonia synthesis
# 45             DKS  DKS_EG_2030   AT+50%Exp  2030      EG    H2 Electrolysis
# 47             DKS  DKS_EG_2030   AT+50%Exp  2030      EG          H2 export
# 48             DKS  DKS_EG_2030   AT+50%Exp  2030      EG           Industry
# 50             DKS  DKS_EG_2030   AT+50%Exp  2030      EG    Power-to-liquid
# 51             DKS  DKS_EG_2030   AT+50%Exp  2030      EG                SMR
# 52             DKS  DKS_EG_2030   AT+50%Exp  2030      EG             SMR CC
# 53             DKS  DKS_EG_2030   AT+50%Exp  2030      EG           Shipping
# 59             DKS  DKS_EG_2030    AT+NoExp  2030      EG           Industry
# 62             DKS  DKS_EG_2030    AT+NoExp  2030      EG                SMR
# 64             DKS  DKS_EG_2030    AT+NoExp  2030      EG           Shipping
#
#     value
# 0   -37.4
# 1    46.9
# 3    -4.7
# 4    -7.8
# 6    -4.8
# 7     4.4
# 8     3.6
# 9    -0.2
# 11  -18.7
# 12   23.4
# 14   -2.4
# 15   -7.8
# 17   -2.4
# 18    6.2
# 19    1.8
# 20   -0.2
# 44  -18.7
# 45   23.4
# 47   -2.3
# 48  -14.0
# 50   -2.4
# 51   12.6
# 52    1.8
# 53   -0.4
# 59  -14.0
# 62   14.4
# 64   -0.4

# %%
supply_sum_df
# Out:
#                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG        54.9
#                             AB+50%Exp  2030 EG        31.4
#                             AT+50%Exp  2030 EG        37.8
#                             AT+NoExp   2030 EG        14.4

# %%
demand_sum_df
# Out:
#                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG        54.9
#                             AB+50%Exp  2030 EG        31.5
#                             AT+50%Exp  2030 EG        37.8
#                             AT+NoExp   2030 EG        14.4

# %%
fig_name = "hydrogen_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["hydrogen"],
    category_orders={
        "variable":list(colors["hydrogen"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"H2 balance in TWh","year":"",
            "variable":"", 
            "scen": ""},

)

# Add legend groups for Production and Consumption
fig = add_production_consumption_legend_groups(fig, df)

update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG        54.9
#                             AB+50%Exp  2030 EG        31.5
#                             AT+50%Exp  2030 EG        37.8
#                             AT+NoExp   2030 EG        14.4
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="d995f44a-94eb-443b-987a-b072d72b9abe" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d995f44a-94eb-443b-987a-b072d72b9abe")) {                    Plotly.newPlot(                        "d995f44a-94eb-443b-987a-b072d72b9abe",                        [{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzNzR0BmZmZmZmY3QGZmZmZmZjdA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzNzR0BmZmZmZmY3QGZmZmZmZjdA"},"yaxis":"y","type":"bar","legendgrouptitle":{"text":"Production"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzH8AzMzMzMzMfwAAAAAAAACzAAAAAAAAALMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzH8AzMzMzMzMfwAAAAAAAACzAAAAAAAAALMA="},"yaxis":"y","type":"bar","legendgrouptitle":{"text":"Consumption"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Ammonia synthesis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzOzQsAzMzMzM7MywDMzMzMzszLA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzOzQsAzMzMzM7MywDMzMzMzszLA"},"yaxis":"y","type":"bar","legendgrouptitle":{"text":"Consumption"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Power-to-liquid","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzE8AzMzMzMzMDwDMzMzMzMwPA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzE8AzMzMzMzMDwDMzMzMzMwPA"},"yaxis":"y","type":"bar","legendgrouptitle":{"text":"Consumption"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Consumption","marker":{"color":"#4CC2A6","pattern":{"shape":""}},"name":"H2 export","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMEsAzMzMzMzMDwGZmZmZmZgLA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMEsAzMzMzMzMDwGZmZmZmZgLA"},"yaxis":"y","type":"bar","legendgrouptitle":{"text":"Consumption"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Production","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"SMR","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZEUDNzMzMzMwYQDMzMzMzMylAzczMzMzMLEA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZEUDNzMzMzMwYQDMzMzMzMylAzczMzMzMLEA="},"yaxis":"y","type":"bar","legendgrouptitle":{"text":"Production"},"textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eH2 balance in TWh=%{text}\ ...

# %% [markdown]
# ## Energy and feedstock market balance | Liquid fuel

# %%
df = prepare_dataframe(balance_dict["oil"], idx_group, set_scen_col)
df = df[df["value"]!=0]
df.variable = df.variable.map(rename_oil)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "liquid_fuel_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["oil"],
    category_orders={
        "variable":list(colors["oil"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"Liquid fuel balance in TWh","year":"",
            "variable":"", 
            "scen":""},

)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG       319.0
#                             AB+50%Exp  2030 EG       317.3
#                             AB+NoExp   2030 EG       315.5
#                             AT+100%Exp 2030 EG       281.0
#                             AT+50%Exp  2030 EG       279.3
#                             AT+NoExp   2030 EG       277.5
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="2fb68282-a9aa-4e63-b4cb-a019781cf9b3" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2fb68282-a9aa-4e63-b4cb-a019781cf9b3")) {                    Plotly.newPlot(                        "2fb68282-a9aa-4e63-b4cb-a019781cf9b3",                        [{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fossil fuel import","marker":{"color":"#1c3f52","pattern":{"shape":""}},"name":"Fossil fuel import","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAC4c0AAAAAAALhzQAAAAAAAuHNAmpmZmZlZcUCamZmZmVlxQJqZmZmZWXFA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAC4c0AAAAAAALhzQAAAAAAAuHNAmpmZmZlZcUCamZmZmVlxQJqZmZmZWXFA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-liquid","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Power-to-liquid","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAADEDNzMzMzMz8PwAAAAAAAAxAzczMzMzM\u002fD8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAADEDNzMzMzMz8PwAAAAAAAAxAzczMzMzM\u002fD8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Land transport","marker":{"color":"#669db2","pattern":{"shape":""}},"name":"Land transport","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZm5ZsCamZmZmblmwJqZmZmZuWbAAAAAAAAAZcAAAAAAAABlwAAAAAAAAGXA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZm5ZsCamZmZmblmwJqZmZmZuWbAAAAAAAAAZcAAAAAAAABlwAAAAAAAAGXA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maritime","marker":{"color":"#39c1cd","pattern":{"shape":""}},"name":"Maritime","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAI8AAAAAAAAAjwAAAAAAAACPAAAAAAAAAIsAAAAAAAAAiwAAAAAAAACLA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAI8AAAAAAAAAjwAAAAAAAACPAAAAAAAAAIsAAAAAAAAAiwAAAAAAAACLA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aviation","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Aviation","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAADAQcAAAAAAAMBBwAAAAAAAwEHAzczMzMxMQcDNzMzMzExBwM3MzMzMTEHA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAADAQcAAAAAAAMBBwAAAAAAAwEHAzczMzMxMQcDNzMzMzExBwM3MzMzMTEHA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eLiquid fuel balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#f58220","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZlZTMCamZmZmVlMwJqZmZmZWUzAMzMzMzMzRsAzMzMzMzNGwDMzMzMzM0bA"},"textposition":"inside","texttemplate":"%{y:.0f}", ...

# %% [markdown]
# ## Energy and feedstock market balance | CH4

# %%
df = prepare_dataframe(balance_dict["gas"], idx_group, set_scen_col, rename_function=rename_gas)
df = df[df["value"]!=0]
# df.variable = df.variable.map(rename_gas)

# %%
(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "CH4_balance_TWh"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["gas"],
    category_orders={
        "variable":list(colors["gas"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"CH4 balance in TWh","year":"",
            "variable":"", 
            "scen":""},

)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG       227.9
#                             AB+50%Exp  2030 EG       213.9
#                             AB+NoExp   2030 EG       188.4
#                             AT+100%Exp 2030 EG       219.2
#                             AT+50%Exp  2030 EG       204.0
#                             AT+NoExp   2030 EG       187.9
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="80707e0e-1157-477a-938f-dc84236f1280" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("80707e0e-1157-477a-938f-dc84236f1280")) {                    Plotly.newPlot(                        "80707e0e-1157-477a-938f-dc84236f1280",                        [{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas import","marker":{"color":"#fce356","pattern":{"shape":""}},"name":"Gas import","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAACAbEDNzMzMzLxqQM3MzMzMjGdAZmZmZmZma0AzMzMzM4NpQM3MzMzMfGdA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAACAbEDNzMzMzLxqQM3MzMzMjGdAZmZmZmZma0AzMzMzM4NpQM3MzMzMfGdA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":"#d3c7ae","pattern":{"shape":""}},"name":"Gas turbines","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmbGX8AzMzMzM1NcwAAAAAAAAFbAzczMzMzcYMAAAAAAAABewGZmZmZmBlrA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmbGX8AzMzMzM1NcwAAAAAAAAFbAzczMzMzcYMAAAAAAAABewGZmZmZmBlrA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Industry","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Industry","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZl5VsCamZmZmXlWwJqZmZmZeVbAmpmZmZk5UMCamZmZmTlQwJqZmZmZOVDA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZl5VsCamZmZmXlWwJqZmZmZeVbAmpmZmZk5UMCamZmZmTlQwJqZmZmZOVDA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"steam methane reforming","marker":{"color":"#17BECF","pattern":{"shape":""}},"name":"steam methane reforming","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMFsAzMzMzMzMgwAAAAAAAACXAZmZmZmZmLMAAAAAAAIAwwGZmZmZm5jLA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMFsAzMzMzMzMgwAAAAAAAACXAZmZmZmZmLMAAAAAAAIAwwGZmZmZm5jLA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCH4 balance in TWh=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"steam methane reforming CC","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"steam methane reforming CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzMFMDNzMzMzMwEwM3MzMzMzBTAzczMzMzMBMA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMFMDNzMzMzMwEwM3MzMzMzBTAzczMzMzMBMA="},"yaxis":"y","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"en ...

# %% [markdown]
# ## Energy and feedstock market balance | CO2

# %%
df = prepare_dataframe(balance_dict["co2 stored"], idx_group, set_scen_col)
df = df[df["value"]!=0]

df.variable = df.variable.map(rename_co2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["co2"],
    category_orders={
        "variable":list(colors["gas"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    labels={"value":"CO<sub>2</sub> Capture (+) and Usage (-) in Mt","year":"","variable":"", "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", demand_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_CO2_capture_and_usage_Mt")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG         0.9
#                             AB+50%Exp  2030 EG         0.4
#                             AT+100%Exp 2030 EG         0.9
#                             AT+50%Exp  2030 EG         0.4
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="5b56dc7e-8895-42e5-b790-9032ecf76c87" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5b56dc7e-8895-42e5-b790-9032ecf76c87")) {                    Plotly.newPlot(                        "5b56dc7e-8895-42e5-b790-9032ecf76c87",                        [{"hovertemplate":"=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Power-to-liquid","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Power-to-liquid","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM7L+amZmZmZnZv83MzMzMzOy\u002fmpmZmZmZ2b8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM7L+amZmZmZnZv83MzMzMzOy\u002fmpmZmZmZ2b8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO\u003csub\u003e2\u003c\u002fsub\u003e Capture (+) and Usage (-) in Mt=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR CC","marker":{"color":"#8C564B","pattern":{"shape":""}},"name":"SMR CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM7D8AAAAAAADgP83MzMzMzOw\u002fAAAAAAAA4D8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM7D8AAAAAAADgP83MzMzMzOw\u002fAAAAAAAA4D8="},"yaxis":"y","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks": ...

# %% [markdown]
# ## CO2 atmosphere balance

# %%
df = prepare_dataframe(balance_dict["co2"], idx_group, set_scen_col)

df.variable = df.variable.map(rename_co2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "co2_emissions_mt"
fig = px.bar(
    df, 
    **fig_kwargs,
    labels={"value":"CO2 emissions in Mt<sub>CO2</sub>",
            "year":"",
            "variable":"", 
            "scen":""
            },
    color_discrete_map=colors["co2"],
    category_orders={
        "variable":list(colors["co2"].keys()),
        "scen": scen_order
        },
    #facet_col_wrap=1, facet_col_spacing=0.07,
)
fig.update_layout(legend_traceorder="reversed",)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(supply_df, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG       182.6
#                             AB+50%Exp  2030 EG       179.9
#                             AB+NoExp   2030 EG       175.2
#                             AT+100%Exp 2030 EG       171.0
#                             AT+50%Exp  2030 EG       168.1
#                             AT+NoExp   2030 EG       165.2
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="eb2dcac0-f4e9-436c-9c18-fcee9c9a9389" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("eb2dcac0-f4e9-436c-9c18-fcee9c9a9389")) {                    Plotly.newPlot(                        "eb2dcac0-f4e9-436c-9c18-fcee9c9a9389",                        [{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CCGT","marker":{"color":"#7F7F7F","pattern":{"shape":""}},"name":"CCGT","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmAkDNzMzMzMwEQJqZmZmZmbk\u002fmpmZmZmZAUCamZmZmZkBQGZmZmZmZgJA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmAkDNzMzMzMwEQJqZmZmZmbk\u002fmpmZmZmZAUCamZmZmZkBQGZmZmZmZgJA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FT export","marker":{"color":"#BCBD22","pattern":{"shape":""}},"name":"FT export","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzM7D+amZmZmZnZP83MzMzMzOw\u002fmpmZmZmZ2T8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzM7D+amZmZmZnZP83MzMzMzOw\u002fmpmZmZmZ2T8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OCGT","marker":{"color":"#17BECF","pattern":{"shape":""}},"name":"OCGT","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmbmNkBmZmZmZuYzQM3MzMzMTDFAAAAAAACAOECamZmZmZk1QM3MzMzMTDJA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmbmNkBmZmZmZuYzQM3MzMzMTDFAAAAAAACAOECamZmZmZk1QM3MzMzMTDJA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"SMR","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZ8T+amZmZmZn5P83MzMzMzABAZmZmZmZmBkBmZmZmZmYKQJqZmZmZmQ1A"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZ8T+amZmZmZn5P83MzMzMzABAZmZmZmZmBkBmZmZmZmYKQJqZmZmZmQ1A"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR CC","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"SMR CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZuT+amZmZmZm5P5qZmZmZmbk\u002fmpmZmZmZuT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eCO2 emissions in Mt\u003csub\u003eCO2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"co2","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"co2","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmbWZsDNzMzMzHxmwGZmZmZm5mXAMzMzMzNjZcAzMzMzMwN ...

# %%
1e4
# Out:
# 10000.0

# %%
df = prepare_dataframe(optimal_capacity_dict["AC"], idx_group, set_scen_col)
df = df[df["value"]<1e4] #drop loadshedding capacity
df.variable = df.variable.map(rename_electricity).map(rename_to_upper_case)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "electricity_installed_capacity_GW"
fig = px.bar(
    df, 
    **fig_kwargs,
    #barmode="stack",
    color_discrete_map=colors["electricity"],
    category_orders={
        "variable":list(colors["electricity"].keys()),
        "scen": scen_order
        },
    #facet_col_spacing=0.1,
    #range_y=(0,supply_sum_df.max().value*1.1),
    labels={"value":"Installed capacity in GW<sub>el</sub>","year":"",
            #"variable":"",
            "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                      value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG       207.6
#                             AB+50%Exp  2030 EG       185.4
#                             AB+NoExp   2030 EG       167.4
#                             AT+100%Exp 2030 EG       218.8
#                             AT+50%Exp  2030 EG       197.2
#                             AT+NoExp   2030 EG       175.1
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="c4025626-c2d6-4189-9c2d-5c5cf4cdcac8" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c4025626-c2d6-4189-9c2d-5c5cf4cdcac8")) {                    Plotly.newPlot(                        "c4025626-c2d6-4189-9c2d-5c5cf4cdcac8",                        [{"hovertemplate":"variable=Solar PV\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar PV","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar PV","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"zczMzMzsZUBmZmZmZkZjQJqZmZmZSWFAzczMzMw8Z0DNzMzMzKxkQGZmZmZmFmJA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzsZUBmZmZmZkZjQJqZmZmZSWFAzczMzMw8Z0DNzMzMzKxkQGZmZmZmFmJA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Wind onshore\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind onshore","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind onshore","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZm\u002fj9mZmZmZmb+P2ZmZmZmZv4\u002fZmZmZmZm\u002fj9mZmZmZmb+P2ZmZmZmZv4\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZm\u002fj9mZmZmZmb+P2ZmZmZmZv4\u002fZmZmZmZm\u002fj9mZmZmZmb+P2ZmZmZmZv4\u002f"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Hydro\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hydro","marker":{"color":"#a6bbc8","pattern":{"shape":""}},"name":"Hydro","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002fMzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002fMzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002fMzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002fMzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002fMzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+100%Exp","AB+100%Exp","AB+50%Exp","AB+50%Exp","AB+50%Exp","AB+NoExp","AB+NoExp","AB+NoExp","AT+100%Exp","AT+100%Exp","AT+100%Exp","AT+50%Exp","AT+50%Exp","AT+50%Exp","AT+NoExp","AT+NoExp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002fMzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002fMzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002fMzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002fMzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002fMzMzMzMzA0BmZmZmZmYGQJqZmZmZmbk\u002f"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Nuclear\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nuclear","marker":{"color":"#bb0056","pattern":{"shape":""}},"name":"Nuclear","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzE0AzMzMzMzMTQDMzMzMzMxNAMzMzMzMzE0AzMzMzMzMTQDMzMzMzMxNA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzE0AzMzMzMzMTQDMzMzMzMxNAMzMzMzMzE0AzMzMzMzMTQDMzMzMzMxNA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Gas turbines\u003cbr\u003e=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eel\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gas turbines","marker":{"color":" ...

# %%
df = prepare_dataframe(optimal_capacity_dict["H2"], idx_group, set_scen_col)
df = df[df["value"]<1e6] #drop loadshedding capacity
df.variable = df.variable.map(rename_h2)

(supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df)

# %%
fig_name = "hydrogen_installed_capacity_GW"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map={"H2 Electrolysis":"#179c7d"},
    category_orders={
        #"variable":list(colors["gas"].keys())
        "scen": scen_order
        },
    labels={"value":"Installed capacity in GW<sub>H2</sub>","year":"","variable":"","scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_{fig_name}")
# Out:
# Totals per scenario and year:                                                        value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG       13506.4
#                             AB+50%Exp  2030 EG       13503.6
#                             AB+NoExp   2030 EG       13500.9
#                             AT+100%Exp 2030 EG       13507.2
#                             AT+50%Exp  2030 EG       13504.4
#                             AT+NoExp   2030 EG       13501.6
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="2f461e1e-2e8a-4bfa-b9f7-e8450246dd00" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2f461e1e-2e8a-4bfa-b9f7-e8450246dd00")) {                    Plotly.newPlot(                        "2f461e1e-2e8a-4bfa-b9f7-e8450246dd00",                        [{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAAFkCamZmZmZkFQGZmZmZmZhZAZmZmZmZmBkA="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAFkCamZmZmZkFQGZmZmZmZhZAZmZmZmZmBkA="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR","marker":{"color":"#FF7F0E","pattern":{"shape":""}},"name":"SMR","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAAAA4D9mZmZmZmbmP83MzMzMzOw\u002fMzMzMzMz8z9mZmZmZmb2P5qZmZmZmfk\u002f"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA4D9mZmZmZmbmP83MzMzMzOw\u002fMzMzMzMz8z9mZmZmZmb2P5qZmZmZmfk\u002f"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SMR CC","marker":{"color":"#2CA02C","pattern":{"shape":""}},"name":"SMR CC","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZ2T+amZmZmZnJP5qZmZmZmdk\u002fmpmZmZmZyT8="},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZ2T+amZmZmZnJP5qZmZmZmdk\u002fmpmZmZmZyT8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"=%{x}\u003cbr\u003eInstalled capacity in GW\u003csub\u003eH2\u003c\u002fsub\u003e=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"load shedding","marker":{"color":"#D62728","pattern":{"shape":""}},"name":"load shedding","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"AAAAAABeykAAAAAAAF7KQAAAAAAAXspAAAAAAABeykAAAAAAAF7KQAAAAAAAXspA"},"textposition":"inside","texttemplate":"%{y:.0f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAABeykAAAAAAAF7KQAAAAAAAXspAAAAAAABeykAAAAAAAF7KQAAAAAAAXspA"},"yaxis":"y","type":"bar","textangle":0}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"co ...

# %%
stats_df = pd.concat([costs_dict["capex"],costs_dict["opex"]],axis=0)
df = prepare_dataframe(stats_df, idx_group, set_scen_col)
df.variable = df.variable.map(rename_costs) # ToDo rename important cost components
df = df.groupby(["run_name_prefix", "scen", "year", "country", "variable"], as_index=False).sum().round(1)
df = df[df["value"]!=0]

# (supply_df, supply_sum_df, demand_df, demand_sum_df) = get_supply_demand_from_balance(df, threshold=0., round=1)

# %%
fig_name = "system_costs_billion_eur" # expenditure and export revenue
fig_kwargs["height"] = heights["3"]
fig_kwargs["text_auto"] = ".1f"
fig = px.bar(
    df, 
    **fig_kwargs,
    color_discrete_map=colors["costs"],
    category_orders={
        "variable":list(colors["costs"].keys()),
        #"scen": scen_order
        },
    facet_col_spacing=0.1,
    labels={"value":"System costs in billion EUR20XX/year","year":"", 
            #"variable":"", 
            "scen":""},
)
update_layout(fig)

print("Totals per scenario and year:", supply_sum_df)
fig.show()
#save_plotly_fig(df, fig, fig, sdir, f"{idx_group_name}_installed_capacity_AC_GW")
# Out:
# Totals per scenario and year:                                                        value
# run_name_prefix run_name    scen       year country
# DKS             DKS_EG_2030 AB+100%Exp 2030 EG       13506.4
#                             AB+50%Exp  2030 EG       13503.6
#                             AB+NoExp   2030 EG       13500.9
#                             AT+100%Exp 2030 EG       13507.2
#                             AT+50%Exp  2030 EG       13504.4
#                             AT+NoExp   2030 EG       13501.6
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="375c44e6-08f8-4d7e-bfa2-1063df1d01eb" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("375c44e6-08f8-4d7e-bfa2-1063df1d01eb")) {                    Plotly.newPlot(                        "375c44e6-08f8-4d7e-bfa2-1063df1d01eb",                        [{"hovertemplate":"variable=Solar\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Solar","marker":{"color":"#fdb913","pattern":{"shape":""}},"name":"Solar","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZKUBmZmZmZmYmQDMzMzMzMyRAAAAAAAAAK0AzMzMzMzMoQAAAAAAAACVA"},"textposition":"inside","texttemplate":"%{y:.1f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZKUBmZmZmZmYmQDMzMzMzMyRAAAAAAAAAK0AzMzMzMzMoQAAAAAAAACVA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Wind\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wind","marker":{"color":"#005b7f","pattern":{"shape":""}},"name":"Wind","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"mpmZmZmZ2T+amZmZmZnZP5qZmZmZmdk\u002fmpmZmZmZ2T+amZmZmZnZP5qZmZmZmdk\u002f"},"textposition":"inside","texttemplate":"%{y:.1f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmZmZ2T+amZmZmZnZP5qZmZmZmdk\u002fmpmZmZmZ2T+amZmZmZnZP5qZmZmZmdk\u002f"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=H2 Electrolysis\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"H2 Electrolysis","marker":{"color":"#179c7d","pattern":{"shape":""}},"name":"H2 Electrolysis","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMz+z\u002fNzMzMzMzsPzMzMzMzM\u002fs\u002fzczMzMzM7D8="},"textposition":"inside","texttemplate":"%{y:.1f}","x":["AB+100%Exp","AB+50%Exp","AT+100%Exp","AT+50%Exp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMz+z\u002fNzMzMzMzsPzMzMzMzM\u002fs\u002fzczMzMzM7D8="},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Transmission line\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Transmission line","marker":{"color":"#4cc2a6","pattern":{"shape":""}},"name":"Transmission line","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"ZmZmZmZmHkBmZmZmZmYeQGZmZmZmZh5AZmZmZmZmHkBmZmZmZmYeQGZmZmZmZh5A"},"textposition":"inside","texttemplate":"%{y:.1f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmHkBmZmZmZmYeQGZmZmZmZh5AZmZmZmZmHkBmZmZmZmYeQGZmZmZmZh5A"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Oil\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oil","marker":{"color":"#C0C0C0","pattern":{"shape":""}},"name":"Oil","orientation":"v","showlegend":true,"text":{"dtype":"f8","bdata":"MzMzMzMzJkAzMzMzMzMmQGZmZmZmZiZAzczMzMzMI0DNzMzMzMwjQM3MzMzMzCNA"},"textposition":"inside","texttemplate":"%{y:.1f}","x":["AB+100%Exp","AB+50%Exp","AB+NoExp","AT+100%Exp","AT+50%Exp","AT+NoExp"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzJkAzMzMzMzMmQGZmZmZmZiZAzczMzMzMI0DNzMzMzMwjQM3MzMzMzCNA"},"yaxis":"y","type":"bar","textangle":0},{"hovertemplate":"variable=Gas\u003cbr\u003e=%{x}\u003cbr\u003eSystem costs in billion EUR20XX\u002fyear=%{text}\u003cextra\u003e\u003c\u002fextra\u003e"," ...

# %% [markdown]
# ## Relative costs
#
# costs / total energy consumption

# %% [markdown]
# ## Water consumption
