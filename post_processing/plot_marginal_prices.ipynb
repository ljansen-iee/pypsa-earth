# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import pandas as pd
idx_slice = pd.IndexSlice
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # Comment out for debugging and development
warnings.simplefilter(action='ignore', category=DeprecationWarning) # Comment out for debugging and development
import plotly.graph_objects as go
import plotly.express as px

import pypsa

from plot_helpers import (
    INDEX_COLS,
    chdir_to_root_dir,
    read_stats_dict,
    drop_index_levels,
    prepare_dataframe,
    nice_title,
    save_plotly_fig,
    read_csv_nafix)

chdir_to_root_dir()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
RUN_NAME_PREFIX = "MAPaper" # Experiment name
SDIR = Path.cwd() / "results"/ f"{RUN_NAME_PREFIX}_summary_v3"
SDIR.mkdir(exist_ok=True, parents=True)

COUNTRIES = ['MA'] #, 'EG', 'MA', 'ZA', 'CL'

INDEX_LEVELS_TO_DROP=["simpl", "clusters", "discountrate", "ll"] #, , "ll" "opts", "demand" "sopts"

# select and define index group (multiindex) for plots: which solutions to show at once

# IDX_GROUP = idx_slice[["DKS"],:,COUNTRIES,[2030, 2050],["1H"]]
IDX_GROUP = idx_slice[[RUN_NAME_PREFIX],:,COUNTRIES,[2035]]
IDX_GROUP_NAME = "".join(COUNTRIES) + "_MAIN"

print(IDX_GROUP_NAME) 
print(IDX_GROUP)

SCEN_FILTER = ['Exp-H2v1.0', 
               'Exp-H2v1.0-Co2L1.09',
               'Exp-H2v1.0-high_wind',
               'Exp-H2v1.0-low_wind',
               'IR-HBIv1.0+STEELv1.0',
               'IR-HBIv1.0+STEELv1.0-Co2L1.09',
               'IR-HBIv1.0+STEELv1.0-high_wind',
               'IR-HBIv1.0+STEELv1.0-low_wind',
               ]
# 'Exp', 'Exp-Co2L1.09', 'Exp-H2v1.0', 'Exp-H2v1.0-Co2L1.09',
#        'Exp-HBIv1.0+STEELv1.0', 'Exp-HBIv1.0+STEELv1.0-Co2L1.09', 'IR',
#        'IR-Co2L1.09', 'IR-H2v1.0-Co2L1.09', 'IR-HBIv1.0+STEELv1.0',
#        'IR-HBIv1.0+STEELv1.0-Co2L1.09'

scen_order = SCEN_FILTER if SCEN_FILTER else [] #[] # option to specify order of scenarios in the plot
# Out:
# MA_MAIN
# (['MAPaper'], slice(None, None, None), ['MA'], [2035])

# %%
def set_scen_col_MAPaper(df):
    """
    Set combined scenario str (for plots).
    NB: This is specific to the experiment and should be adapted for other experiments.
    """
    df = df.copy()
    
    # Set base scen value based on 'demand'
    demand_info = df["demand"]#.map({"Exp": ""})

    # Add export info based on 'eopts', handling NaN and string values
    export_info = (
        df["eopts"].apply(lambda x: 
            x if isinstance(x, str) and "v" in x
            else ("" if pd.isna(x) or str(x) == "" else str(x))
        )
        .replace("", "", regex=False)
        .apply(lambda x: f"-{x}" if x else "")
    )


    sopts_info = df["sopts"].replace("1H", "", regex=False).apply(lambda x: f"-{x}" if x else "")

    opts_info = (
        df["opts"].apply(
            lambda x: x if isinstance(x, str) and "Co2L" in x
            else ("" if pd.isna(x) or str(x) == "" else x)
        )
        .replace("", "", regex=False)
        .apply(lambda x: f"-{x}" if x else "")
    )

    # ll_info = df["ll"].replace("", "", regex=False).apply(lambda x: f"-{x}" if x else "")

    meteo_type_info = df["run_name"].apply(
        lambda x: "-low_wind" if "worst" in x else("-high_wind" if "best" in x else "")
    )

    # Combine
    df["scen"] = demand_info + export_info + sopts_info + opts_info + meteo_type_info  # + ll_info

    df = df.drop(columns=["eopts", "sopts", "demand", "opts", ]) #"ll"
    #df["scen"] = df.apply(lambda row: "_".join([f"{col}_{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)
    #df["scen"] = df.apply(lambda row: "_".join([f"{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)

    return df

def set_scen_col_DKS(df):
    """
    Set combined scenario str (for plots).
    NB: This is specific to the experiment and should be adapted for other experiments.
    """
    df = df.copy()
    
    # Set base scen value based on 'demand'
    scen = df["demand"].map({"RF": "AB", "EL": "AT"})
    # Add export info
    export_info = ""
    # Add export info based on 'eopts', handling NaN and string values
    export_info = df["eopts"].apply(
        lambda x: "50EX" if isinstance(x, str) and "v0.5" in x
        else ("" if pd.isna(x) or str(x) == "" else "100EX")
    )
    # Combine
    df["scen"] = scen + export_info.replace("", "", regex=False).apply(lambda x: f"-{x}" if x else "") + df["sopts"].replace("1H", "", regex=False)
    df = df.drop(columns=["eopts", "sopts", "demand"])
    #df["scen"] = df.apply(lambda row: "_".join([f"{col}_{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)
    #df["scen"] = df.apply(lambda row: "_".join([f"{row[col]}" for col in df.columns if col not in cols_to_ignore]), axis=1)

    return df

set_scen_col = set_scen_col_MAPaper

# %%
mean_marginal_prices = read_csv_nafix(SDIR / "time_avg_marginal_price.csv", index_col=INDEX_COLS)
mean_marginal_prices = drop_index_levels(mean_marginal_prices, INDEX_LEVELS_TO_DROP)

nc_files = read_csv_nafix(SDIR / "nc_files.csv", index_col=INDEX_COLS)
nc_files = drop_index_levels(nc_files, INDEX_LEVELS_TO_DROP)

# %%
mean_marginal_prices
# Out:
#                                                                                           H2 export  \
# run_name_prefix run_name           country year opts     sopts demand eopts
# MAPaper         MAPaper_2035       MA      2035 Co2L1.09 1H    Exp    H2v1.0             108.110348
#                                                                IR     HBIv1.0+STEELv1.0         NaN
#                                                 NaN      1H    Exp    H2v1.0             105.683352
#                                                                IR     HBIv1.0+STEELv1.0         NaN
#                 MAPaper_2035_best  MA      2035 Co2L1.09 1H    Exp    H2v1.0             101.788460
#                                                                       HBIv1.0+STEELv1.0         NaN
#                                                                IR     H2v1.0              93.562885
#                                                                       HBIv1.0+STEELv1.0         NaN
# ...

# %%
#df = df.query("variable in ['FT export bus']")

# %%
width = 800
heights = {"1": 350,"2": 500,"3": 600,}

fig_kwargs = dict(
    x="scen", 
    y="value", 
    color="variable", 
    facet_col="year", 
    # facet_row="run_name",
    barmode="relative", 
    text="value", 
    #facet_col_wrap=1, facet_col_spacing=0.07,
    width=width, 
    height=heights["2"],
    text_auto =".0f",
)

# %% [markdown]
# # Plot time average (annual) marginal prices

# %%
def categorize_variable(x):
    if "H2 export" in x:
        return "H2 export"
    elif "AC H2" in x:
        return "H2 domestic average"
    elif "NH3 export" in x:
        return "NH3 export"
    elif "AC NH3" in x:
        return "NH3 domestic average"
    elif "AC methanol" in x:
        return "Methanol domestic average"
    elif "STEEL export" in x:
        return "Steel export"
    elif "Earth steel" in x:
        return "Steel domestic average"
    elif "HBI export" in x:
        return "HBI export"
    elif "Earth HBI" in x:
        return "HBI domestic average"
    else:
        return x

df = prepare_dataframe(
    mean_marginal_prices, 
    IDX_GROUP,
    set_scen_col_name=set_scen_col,
)
df = df[df["value"]>0]

# %%
df
# Out:
#      run_name_prefix            run_name                           scen  year  \
# 0            MAPaper        MAPaper_2035                     Exp-H2v1.0  2035
# 1            MAPaper        MAPaper_2035                     Exp-H2v1.0  2035
# 3            MAPaper        MAPaper_2035                     Exp-H2v1.0  2035
# 5            MAPaper        MAPaper_2035                     Exp-H2v1.0  2035
# 8            MAPaper        MAPaper_2035                     Exp-H2v1.0  2035
# ...              ...                 ...                            ...   ...
# 1628         MAPaper  MAPaper_2035_worst  IR-HBIv1.0+STEELv1.0-low_wind  2035
# 1631         MAPaper  MAPaper_2035_worst  IR-HBIv1.0+STEELv1.0-low_wind  2035
# 1633         MAPaper  MAPaper_2035_worst  IR-HBIv1.0+STEELv1.0-low_wind  2035
# 1636         MAPaper  MAPaper_2035_worst  IR-HBIv1.0+STEELv1.0-low_wind  2035
# 1639         MAPaper  MAPaper_2035_worst  IR-HBIv1.0+STEELv1.0-low_wind  2035
#
# ...

# %%
SCEN_FILTER
# Out:
# ['Exp-H2v1.0',
#  'Exp-H2v1.0-Co2L1.09',
#  'Exp-H2v1.0-high_wind',
#  'Exp-H2v1.0-low_wind',
#  'IR-HBIv1.0+STEELv1.0',
#  'IR-HBIv1.0+STEELv1.0-Co2L1.09',
#  'IR-HBIv1.0+STEELv1.0-high_wind',
#  'IR-HBIv1.0+STEELv1.0-low_wind']

# %%
df["category"] = df["variable"].apply(categorize_variable)

# %%
df = df.groupby(["scen", "year","country","category"]).mean(numeric_only=True).reset_index().round(0)
df = df.query("scen in @SCEN_FILTER") if SCEN_FILTER else df if SCEN_FILTER else df
df = df.query("category in ['H2 domestic average', 'H2 export','NH3 domestic average','Steel export','HBI export']")

# %%
df
# Out:
#                                scen  year country              category  value
# 0                        Exp-H2v1.0  2035      MA   H2 domestic average  110.0
# 1                        Exp-H2v1.0  2035      MA             H2 export  106.0
# 4                        Exp-H2v1.0  2035      MA  NH3 domestic average  153.0
# 6               Exp-H2v1.0-Co2L1.09  2035      MA   H2 domestic average  116.0
# 7               Exp-H2v1.0-Co2L1.09  2035      MA             H2 export  108.0
# 10              Exp-H2v1.0-Co2L1.09  2035      MA  NH3 domestic average  161.0
# 24             Exp-H2v1.0-high_wind  2035      MA   H2 domestic average  108.0
# 25             Exp-H2v1.0-high_wind  2035      MA             H2 export  103.0
# 28             Exp-H2v1.0-high_wind  2035      MA  NH3 domestic average  151.0
# 30              Exp-H2v1.0-low_wind  2035      MA   H2 domestic average  110.0
# 31              Exp-H2v1.0-low_wind  2035      MA             H2 export  109.0
# ...

# %%
# Create scatter plot with category as color (flipped axes)
fig = px.scatter(
    df, 
        x="value", 
            y="scen", 
                color="category",
                    text="value",
                        title="Marginal Prices by Scenario and Category in 2035",
                            labels={
                                    "scen": "Scenario",
                                            "value": "Marginal Price [EUR/MWh or EUR/t]",
                                                    "category": "Category"
                                                        },
                                                            width=1000,
                                                                height=400,
                                                                    hover_data=["country", "year"]
                                                                    )

                                                                    # Update layout for better readability
                                                                    fig.update_layout(
                                                                        # xaxis_title="Marginal Price [EUR/MWh]",
                                                                            yaxis_title="Scenario",
                                                                                legend_title="Category",
                                                                                    hovermode='closest'
                                                                                    )

                                                                                    # Update traces for better visibility
                                                                                    fig.update_traces(
                                                                                        marker=dict(size=10, opacity=0.8),
                                                                                            mode='markers+text',
                                                                                                textposition='middle right',
                                                                                                    textfont=dict(size=10)
                                                                                                    )

                                                                                                    fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plot hourly marginal prices for NH3 for multiple countries

# %%
# Improved filtering and selection of nc_file for pypsa.Network
# Example: filter for Egypt, year 2050, 1H, demand 'EL', scenario 'H2v0.5+NH3v0.5+FTv0.5'
filtered_nc = nc_files.reset_index().query("country == 'MA' and year == 2035 and sopts == '1H' and eopts == 'HBIv1.0+STEELv1.0'")
if not filtered_nc.empty:
    nc_file_path = filtered_nc.iloc[0]['file']
else:
    nc_file_path = None  # or handle error
nc_file_path

n = pypsa.Network(nc_file_path)
# Out:
# WARNING	pypsa.network.io:io.py:_import_from_importer()- Importing network from PyPSA version v0.0.0 while current version is v0.35.1. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.

# %%
import plotly.express as px
countries = ["EG", "CL", "MA", "ZA"]
country_labels = {"EG": "Egypt", "CL": "Chile", "MA": "Morocco", "ZA": "South Africa"}
fig_data = []

# Debug: Check what's available for each country
print("Available data for each country:")
for country in countries:
    available = nc_files.reset_index().query(f"country == '{country}' and year == {YEARS[0]}")
    print(f"{country}: {len(available)} files")
    if not available.empty:
        print(f"  Available scenarios: {available['eopts'].unique()}")
        print(f"  Available demands: {available['demand'].unique()}")

for country in countries:
    # Try different filtering approaches for both demand scenarios
    for demand_type in ['EL', 'RF', 'Exp','IR']:
        filtered_nc = nc_files.reset_index().query(f"country == '{country}' and year == {YEARS[0]} and sopts == '1H' and demand == '{demand_type}' and eopts == 'HBIv1.0+STEELv1.0'")
        
        # If no data with exact match, try different filter
        if filtered_nc.empty:
            filtered_nc = nc_files.reset_index().query(f"country == '{country}' and year == {YEARS[0]} and sopts == '1H' and demand == '{demand_type}' and eopts == 'HBIv1.0+STEELv1.0'")
        
        if not filtered_nc.empty:
            nc_file_path = filtered_nc.iloc[0]['file']
            print(f"Loading network for {country} ({demand_type}): {nc_file_path}")
            n = pypsa.Network(nc_file_path)
            
            # Check available buses
            nh3_buses = [bus for bus in n.buses.index if "NH3" in bus]
            print(f"  NH3 buses for {country} ({demand_type}): {nh3_buses}")
            
            # Try to find NH3 export bus or similar
            nh3_export_bus = None
            if "NH3 export" in n.buses.index:
                nh3_export_bus = "NH3 export"
            elif nh3_buses:
                nh3_export_bus = nh3_buses[0]  # Use first NH3 bus if export bus not found
                print(f"  Using {nh3_export_bus} instead of 'NH3 export bus'")
            
            if nh3_export_bus and nh3_export_bus in n.buses_t.marginal_price.columns:
                prices = n.buses_t.marginal_price[nh3_export_bus] * 5.17
                demand_label = "AT" if demand_type == "EL" else "AB"
                demand_label = "H2" if demand_type == "Exp" else "IR"
                country_name = f"{country_labels[country]} ({demand_label})"
                fig_data.append({
                    "hour": prices.index,
                    "price": prices.values,
                    "country": [country_name] * len(prices)
                })
                print(f"  Added data for {country} ({demand_type}) with {len(prices)} hourly prices")
            else:
                print(f"  No NH3 marginal price data found for {country} ({demand_type})")
        else:
            print(f"  No network files found for {country} ({demand_type})")

import pandas as pd
if fig_data:
    plot_df = pd.concat([pd.DataFrame(d) for d in fig_data], ignore_index=True)
    
    # Create stepwise line plot
    fig = px.line(plot_df, x="hour", y="price", color="country", 
                  title=f"Hourly Marginal Prices for NH3 Export Bus ({YEARS[0]})",
                  line_shape='hv')  # Use 'hv' for horizontal-vertical stepwise lines
    
    # Update layout for better appearance
    fig.update_layout(
        yaxis_title="Marginal Price [EUR/MWh]", 
        xaxis_title="Hour",
        width=800,
        height=600,
        hovermode='x unified'
    )
    
    # Update traces for smoother appearance
    fig.update_traces(
        line=dict(width=2),
        mode='lines'  # Remove markers for smoother appearance, use 'lines+markers' to add them back
    )
    
    fig.show()
    print(f"Plotted data for {plot_df['country'].nunique()} countries: {plot_df['country'].unique()}")
else:
    print("No data available for selected countries.")
# Out:
# Available data for each country:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 9
#       7 print("Available data for each country:")
#       8 for country in countries:
# ----> 9     available = nc_files.reset_index().query(f"country == '{country}' and year == {YEARS[0]}")
#      10     print(f"{country}: {len(available)} files")
#      11     if not available.empty:
#
# NameError: name 'YEARS' is not defined

# %%
840/1.07
# Out:
# 785.0467289719626

# %% [markdown]
# # Plot time-average, min, max for NH3 for multiple countries

# %% [markdown]
# # Plot theory charts
#
# Plot theoretical supply and demand curves for trading green NH3 between Suez Canal and Rotterdamm - illustrating the impact of trade/transport costs and local demand in Suez Canal.
